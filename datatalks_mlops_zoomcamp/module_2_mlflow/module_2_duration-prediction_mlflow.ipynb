# %%
# !python -V
# Out:
# Python 3.12.7

# %% [markdown]
# # Run MLFlow service with Sqlite backend

# %%
# !mlflow ui --backend-store-uri sqlite:///mlflow.db
# Out:
#   Cell In[2], line 1
#     mlflow ui --backend-store-uri sqlite:///mlflow.db
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Import and Setup MLFlow library

# %%
import mlflow

mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("mlops-experiment")
# Out:
# 2025/05/25 11:52:31 INFO mlflow.tracking.fluent: Experiment with name 'mlops-experiment' does not exist. Creating a new experiment.
# <Experiment: artifact_location='/home/ubuntu/jupyter_notebooks_archive/datatalks_mlops_zoomcamp/module_2_mlflow/mlruns/1', creation_time=1748173951772, experiment_id='1', last_update_time=1748173951772, lifecycle_stage='active', name='mlops-experiment', tags={}>

# %% [markdown]
# # Train and Evaluate model

# %%
import pandas as pd

# %%
import pickle

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge

from sklearn.metrics import root_mean_squared_error

# %%
def read_dataframe(filename):
    df = pd.read_parquet(filename)

    df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
    df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)

    df['duration'] = df.lpep_dropoff_datetime - df.lpep_pickup_datetime
    df.duration = df.duration.apply(lambda td: td.total_seconds() / 60)

    df = df[(df.duration >= 1) & (df.duration <= 60)]

    categorical = ['PULocationID', 'DOLocationID']
    df[categorical] = df[categorical].astype(str)
    
    return df

# %%
train_file = '../data/green_tripdata_2025-01.parquet'
val_file = '../data/green_tripdata_2025-02.parquet'

df_train = read_dataframe(train_file)
df_val = read_dataframe(val_file)

# %%
len(df_train), len(df_val)
# Out:
# (46307, 44218)

# %%
df_train['PU_DO'] = df_train['PULocationID'] + '_' + df_train['DOLocationID']
df_val['PU_DO'] = df_val['PULocationID'] + '_' + df_val['DOLocationID']

# %%
categorical = ['PU_DO'] #'PULocationID', 'DOLocationID']
numerical = ['trip_distance']

dv = DictVectorizer()

train_dicts = df_train[categorical + numerical].to_dict(orient='records')
X_train = dv.fit_transform(train_dicts)

val_dicts = df_val[categorical + numerical].to_dict(orient='records')
X_val = dv.transform(val_dicts)

# %%
target = 'duration'
y_train = df_train[target].values
y_val = df_val[target].values

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_val)

root_mean_squared_error(y_val, y_pred)
# Out:
# 6.0988780535504485

# %%
with open('models/lin_reg.bin', 'wb') as f_out:
    pickle.dump((dv, lr), f_out)

# %%
with mlflow.start_run():

    mlflow.set_tag("developer", "cristian")

    mlflow.log_param("train-data-path", train_file)
    mlflow.log_param("valid-data-path", val_file)

    alpha = 0.1
    mlflow.log_param("alpha", alpha)
    lr = Lasso(alpha)
    lr.fit(X_train, y_train)

    y_pred = lr.predict(X_val)
    rmse = root_mean_squared_error(y_val, y_pred)
    mlflow.log_metric("rmse", rmse)

    mlflow.log_artifact(local_path="models/lin_reg.bin", artifact_path="models_pickle")

# %%
import xgboost as xgb

# %%
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope

# %%
train = xgb.DMatrix(X_train, label=y_train)
valid = xgb.DMatrix(X_val, label=y_val)

# %%
def objective(params):
    with mlflow.start_run():
        mlflow.set_tag("model", "xgboost")
        mlflow.log_params(params)
        booster = xgb.train(
            params=params,
            dtrain=train,
            num_boost_round=1000,
            evals=[(valid, 'validation')],
            early_stopping_rounds=50
        )
        y_pred = booster.predict(valid)
        rmse = root_mean_squared_error(y_val, y_pred)
        mlflow.log_metric("rmse", rmse)

    return {'loss': rmse, 'status': STATUS_OK}

# %%
search_space = {
    'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
    'learning_rate': hp.loguniform('learning_rate', -3, 0),
    'reg_alpha': hp.loguniform('reg_alpha', -5, -1),
    'reg_lambda': hp.loguniform('reg_lambda', -6, -1),
    'min_child_weight': hp.loguniform('min_child_weight', -1, 3),
    'objective': 'reg:linear',
    'seed': 42
}

best_result = fmin(
    fn=objective,
    space=search_space,
    algo=tpe.suggest,
    max_evals=50,
    trials=Trials()
)
# Out:
#   0%|                                                                                                | 0/50 [00:00<?, ?trial/s, best loss=?]
# /home/ubuntu/anaconda3/lib/python3.12/site-packages/xgboost/callback.py:386: UserWarning: [11:55:12] WARNING: /workspace/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation-rmse:8.71909
# [1]	validation-rmse:8.36982
# [2]	validation-rmse:8.05425
# [3]	validation-rmse:7.77024
# [4]	validation-rmse:7.51461
# [5]	validation-rmse:7.28642
# [6]	validation-rmse:7.07874
# [7]	validation-rmse:6.89659
# [8]	validation-rmse:6.73271
# [9]	validation-rmse:6.59272
# [10]	validation-rmse:6.46026
# [11]	validation-rmse:6.35050
# [12]	validation-rmse:6.25181
# [13]	validation-rmse:6.16068
# [14]	validation-rmse:6.08429
# [15]	validation-rmse:6.01785
# [16]	validation-rmse:5.96166
# [17]	validation-rmse:5.90341
# [18]	validation-rmse:5.86038
# [19]	validation-rmse:5.81993
# [20]	validation-rmse:5.78405
# [21]	validation-rmse:5.75410
# [22]	validation-rmse:5.72302
# [23]	validation-rmse:5.70027
# [24]	validation-rmse:5.67843
# [25]	validation-rmse:5.66228
# [26]	validation-rmse:5.64241
# [27]	validation-rmse:5.62985
# [28]	validation-rmse:5.61478
# [29]	validation-rmse:5.60626
# [30]	validation-rmse:5.59781
# [31]	validation-rmse:5.58817
# [32]	validation-rmse:5.58262
# [33]	validation-rmse:5.57742
# [34]	validation-rmse:5.56992
# [35]	validation-rmse:5.56580
# [36]	validation-rmse:5.56227
# [37]	validation-rmse:5.55788
# [38]	validation-rmse:5.55586
# [39]	validation-rmse:5.55333
# [40]	validation-rmse:5.54992
# [41]	validation-rmse:5.54772
# [42]	validation-rmse:5.54716
# [43]	validation-rmse:5.54348
# [44]	validation-rmse:5.54323
# [45]	validation-rmse:5.54053
# [46]	validation-rmse:5.53952
# [47]	validation-rmse:5.53879
# [48]	validation-rmse:5.53897
# [49]	validation-rmse:5.53748
# [50]	validation-rmse:5.53696
# [51]	validation-rmse:5.53572
# [52]	validation-rmse:5.53485
# [53]	validation-rmse:5.53465
# [54]	validation-rmse:5.53443
# [55]	validation-rmse:5.53439
# [56]	validation-rmse:5.53428
# [57]	validation-rmse:5.53375
# [58]	validation-rmse:5.53349
# [59]	validation-rmse:5.53333
# [60]	validation-rmse:5.53270
# [61]	validation-rmse:5.53246
# [62]	validation-rmse:5.53229
# [63]	validation-rmse:5.53213
# [64]	validation-rmse:5.53147
# [65]	validation-rmse:5.53098
# [66]	validation-rmse:5.53029
# [67]	validation-rmse:5.52959
# [68]	validation-rmse:5.52915
# [69]	validation-rmse:5.52896
# [70]	validation-rmse:5.52870
# [71]	validation-rmse:5.52860
# [72]	validation-rmse:5.52883
# [73]	validation-rmse:5.52815
# [74]	validation-rmse:5.52750
# [75]	validation-rmse:5.52758
# [76]	validation-rmse:5.52720
# [77]	validation-rmse:5.52735
# [78]	validation-rmse:5.52741
# [79]	validation-rmse:5.52676
# [80]	validation-rmse:5.52715
# [81]	validation-rmse:5.52698
# [82]	validation-rmse:5.52640
# [83]	validation-rmse:5.52644
# [84]	validation-rmse:5.52704
# [85]	validation-rmse:5.52693
# [86]	validation-rmse:5.52695
# [87]	validation-rmse:5.52697
# [88]	validation-rmse:5.52626
# [89]	validation-rmse:5.52655
# [90]	validation-rmse:5.52678
# [91]	validation-rmse:5.52639
# [92]	validation-rmse:5.52657
# [93]	validation-rmse:5.52596
# [94]	validation-rmse:5.52599
# [95]	validation-rmse:5.52610
# [96]	validation-rmse:5.52596
# [97]	validation-rmse:5.52615
# [98]	validation-rmse:5.52609
# [99]	validation-rmse:5.52641
# [100]	validation-rmse:5.52574
# [101]	validation-rmse:5.52613
# [102]	validation-rmse:5.52577
# [103]	validation-rmse:5.52580
# [104]	validation-rmse:5.52555
# [105]	validation-rmse:5.52538
# [106]	validation-rmse:5.52549
# [107]	validation-rmse:5.52549
# [108]	validation-rmse:5.52515
# [109]	validation-rmse:5.52561
# [110]	validation-rmse:5.52526
# [111]	validation-rmse:5.52489
# [112]	validation-rmse:5.52492
# [113]	validation-rmse:5.52511
# [114]	validation-rmse:5.52487
# [115]	validation-rmse:5.52490
# [116]	validation-rmse:5.52457
# [117]	validation-rmse:5.52480
# [118]	validation-rmse:5.52518
# [119]	validation-rmse:5.52471
# [120]	validation-rmse:5.52456
# [121]	validation-rmse:5.52470
# [122]	validation-rmse:5.52465
# [123]	validation-rmse:5.52472
# [124]	validation-rmse:5.52489
# [125]	validation-rmse:5.52464
# [126]	validation-rmse:5.52461
# [127]	validation-rmse:5.52419
# [128]	validation-rmse:5.52450
# [129]	validation-rmse:5.52466
# [130]	validation-rmse:5.52445
# [131]	validation-rmse:5.52456
# [132]	validation-rmse:5.52481
# [133]	validation-rmse:5.52430
# [134]	validation-rmse:5.52449
# [135]	validation-rmse:5.52417
# [136]	validation-rmse:5.52456
# [137]	validation-rmse:5.52479
# [138]	validation-rmse:5.52453
# [139]	validation-rmse:5.52449
# [140]	validation-rmse:5.52459
# [141]	validation-rmse:5.52414
# [142]	validation-rmse:5.52441
# [143]	validation-rmse:5.52435
# [144]	validation-rmse:5.52449
# [145]	validation-rmse:5.52441
# [146]	validation-rmse:5.52477
# [147]	validation-rmse:5.52506
# [148]	validation-rmse:5.52484
# [149]	validation-rmse:5.52483
# [150]	validation-rmse:5.52462
# [151]	validation-rmse:5.52485
# [152]	validation-rmse:5.52481
# [153]	validation-rmse:5.52519
# [154]	validation-rmse:5.52507
# [155]	validation-rmse:5.52504
# [156]	validation-rmse:5.52535
# [157]	validation-rmse:5.52509
# [158]	validation-rmse:5.52538
# [159]	validation-rmse:5.52504
# [160]	validation-rmse:5.52523
# [161]	validation-rmse:5.52555
# [162]	validation-rmse:5.52527
# [163]	validation-rmse:5.52529
# [164]	validation-rmse:5.52533
# [165]	validation-rmse:5.52561
# [166]	validation-rmse:5.52539
# [167]	validation-rmse:5.52571
# [168]	validation-rmse:5.52557
# [169]	validation-rmse:5.52557
# [170]	validation-rmse:5.52563
# [171]	validation-rmse:5.52556
# [172]	validation-rmse:5.52573
# [173]	validation-rmse:5.52598
# [174]	validation-rmse:5.52603
# [175]	validation-rmse:5.52616
# [176]	validation-rmse:5.52633
# [177]	validation-rmse:5.52675
# [178]	validation-rmse:5.52663
# [179]	validation-rmse:5.52676
# [180]	validation-rmse:5.52653
# [181]	validation-rmse:5.52660
# [182]	validation-rmse:5.52677
# [183]	validation-rmse:5.52669
# [184]	validation-rmse:5.52680
# [185]	validation-rmse:5.52672
# [186]	validation-rmse:5.52683
# [187]	validation-rmse:5.52714
# [188]	validation-rmse:5.52705
# [189]	validation-rmse:5.52715
# [190]	validation-rmse:5.52700
# [191]	validation-rmse:5.52711
#   2%|█▍                                                                     | 1/50 [00:51<42:21, 51.87s/trial, best loss: 5.527110393290144]
# /home/ubuntu/anaconda3/lib/python3.12/site-packages/xgboost/callback.py:386: UserWarning: [11:56:04] WARNING: /workspace/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation-rmse:6.55599
# [1]	validation-rmse:5.82795
# [2]	validation-rmse:5.63709
# [3]	validation-rmse:5.56119
# [4]	validation-rmse:5.53140
# [5]	validation-rmse:5.50929
# [6]	validation-rmse:5.48364
# [7]	validation-rmse:5.47697
# [8]	validation-rmse:5.47123
# [9]	validation-rmse:5.46813
# [10]	validation-rmse:5.46346
# [11]	validation-rmse:5.46247
# [12]	validation-rmse:5.45878
# [13]	validation-rmse:5.45628
# [14]	validation-rmse:5.45439
# [15]	validation-rmse:5.45258
# [16]	validation-rmse:5.45303
# [17]	validation-rmse:5.45146
# [18]	validation-rmse:5.44923
# [19]	validation-rmse:5.44889
# [20]	validation-rmse:5.44760
# [21]	validation-rmse:5.44632
# [22]	validation-rmse:5.44681
# [23]	validation-rmse:5.44436
# [24]	validation-rmse:5.44358
# [25]	validation-rmse:5.44289
# [26]	validation-rmse:5.44150
# [27]	validation-rmse:5.44058
# [28]	validation-rmse:5.43897
# [29]	validation-rmse:5.43977
# [30]	validation-rmse:5.43962
# [31]	validation-rmse:5.43936
# [32]	validation-rmse:5.44073
# [33]	validation-rmse:5.43991
# [34]	validation-rmse:5.44026
# [35]	validation-rmse:5.43913
# [36]	validation-rmse:5.43883
# [37]	validation-rmse:5.43802
# [38]	validation-rmse:5.43765
# [39]	validation-rmse:5.43801
# [40]	validation-rmse:5.43778
# [41]	validation-rmse:5.43783
# [42]	validation-rmse:5.43797
# [43]	validation-rmse:5.43818
# [44]	validation-rmse:5.43717
# [45]	validation-rmse:5.43736
# [46]	validation-rmse:5.43705
# [47]	validation-rmse:5.43690
# [48]	validation-rmse:5.43748
# [49]	validation-rmse:5.43751
# [50]	validation-rmse:5.43707
# [51]	validation-rmse:5.43698
# [52]	validation-rmse:5.43699
# [53]	validation-rmse:5.43711
# [54]	validation-rmse:5.43729
# [55]	validation-rmse:5.43755
# [56]	validation-rmse:5.43682
# [57]	validation-rmse:5.43684
# [58]	validation-rmse:5.43789
# [59]	validation-rmse:5.43741
# [60]	validation-rmse:5.43528
# [61]	validation-rmse:5.43489
# [62]	validation-rmse:5.43510
# [63]	validation-rmse:5.43498
# [64]	validation-rmse:5.43515
# [65]	validation-rmse:5.43436
# [66]	validation-rmse:5.43469
# [67]	validation-rmse:5.43455
# [68]	validation-rmse:5.43457
# [69]	validation-rmse:5.43418
# [70]	validation-rmse:5.43508
# [71]	validation-rmse:5.43427
# [72]	validation-rmse:5.43499
# [73]	validation-rmse:5.43425
# [74]	validation-rmse:5.43498
# [75]	validation-rmse:5.43542
# [76]	validation-rmse:5.43425
# [77]	validation-rmse:5.43488
# [78]	validation-rmse:5.43437
# [79]	validation-rmse:5.43502
# [80]	validation-rmse:5.43408
# [81]	validation-rmse:5.43502
# [82]	validation-rmse:5.43393
# [83]	validation-rmse:5.43484
# [84]	validation-rmse:5.43496
# [85]	validation-rmse:5.43526
# [86]	validation-rmse:5.43593
# [87]	validation-rmse:5.43595
# [88]	validation-rmse:5.43593
# [89]	validation-rmse:5.43533
# [90]	validation-rmse:5.43563
# [91]	validation-rmse:5.43543
# [92]	validation-rmse:5.43625
# [93]	validation-rmse:5.43599
# [94]	validation-rmse:5.43639
# [95]	validation-rmse:5.43615
# [96]	validation-rmse:5.43625
# [97]	validation-rmse:5.43531
# [98]	validation-rmse:5.43533
# [99]	validation-rmse:5.43537
# [100]	validation-rmse:5.43550
# [101]	validation-rmse:5.43604
# [102]	validation-rmse:5.43660
# [103]	validation-rmse:5.43664
# [104]	validation-rmse:5.43707
# [105]	validation-rmse:5.43586
# [106]	validation-rmse:5.43524
# [107]	validation-rmse:5.43527
# [108]	validation-rmse:5.43572
# [109]	validation-rmse:5.43569
# [110]	validation-rmse:5.43647
# [111]	validation-rmse:5.43674
# [112]	validation-rmse:5.43591
# [113]	validation-rmse:5.43622
# [114]	validation-rmse:5.43592
# [115]	validation-rmse:5.43654
# [116]	validation-rmse:5.43664
# [117]	validation-rmse:5.43698
# [118]	validation-rmse:5.43756
# [119]	validation-rmse:5.43878
# [120]	validation-rmse:5.43877
# [121]	validation-rmse:5.43846
# [122]	validation-rmse:5.43768
# [123]	validation-rmse:5.43822
# [124]	validation-rmse:5.43776
# [125]	validation-rmse:5.43819
# [126]	validation-rmse:5.43763
# [127]	validation-rmse:5.43795
# [128]	validation-rmse:5.43859
# [129]	validation-rmse:5.43897
# [130]	validation-rmse:5.43885
# [131]	validation-rmse:5.43913
#   4%|██▊                                                                    | 2/50 [01:01<21:40, 27.08s/trial, best loss: 5.439248207757186]
# /home/ubuntu/anaconda3/lib/python3.12/site-packages/xgboost/callback.py:386: UserWarning: [11:56:14] WARNING: /workspace/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation-rmse:8.21196
# [1]	validation-rmse:7.53148
# [2]	validation-rmse:7.01406
# [3]	validation-rmse:6.61708
# [4]	validation-rmse:6.33536
# [5]	validation-rmse:6.12472
# [6]	validation-rmse:5.96154
# ...
# [366]	validation-rmse:5.31186
# [367]	validation-rmse:5.31173
# [368]	validation-rmse:5.31196
# [369]	validation-rmse:5.31188
# [370]	validation-rmse:5.31186
# [371]	validation-rmse:5.31183
# [372]	validation-rmse:5.31225
# [373]	validation-rmse:5.31220
# [374]	validation-rmse:5.31225
# [375]	validation-rmse:5.31236
# [376]	validation-rmse:5.31149
# [377]	validation-rmse:5.31111
# [378]	validation-rmse:5.31134
# [379]	validation-rmse:5.31129
# [380]	validation-rmse:5.31099
# [381]	validation-rmse:5.31092
# [382]	validation-rmse:5.31107
# [383]	validation-rmse:5.31097
# [384]	validation-rmse:5.31126
# [385]	validation-rmse:5.31137
# [386]	validation-rmse:5.31132
# [387]	validation-rmse:5.31243
# [388]	validation-rmse:5.31246
# [389]	validation-rmse:5.31214
# [390]	validation-rmse:5.31135
# [391]	validation-rmse:5.31129
# [392]	validation-rmse:5.31124
# [393]	validation-rmse:5.31151
# [394]	validation-rmse:5.31178
# [395]	validation-rmse:5.31117
# [396]	validation-rmse:5.31042
# [397]	validation-rmse:5.31050
# [398]	validation-rmse:5.31069
# [399]	validation-rmse:5.31053
# [400]	validation-rmse:5.31030
# [401]	validation-rmse:5.31040
# [402]	validation-rmse:5.31045
#  98%|█████████████████████████████████████████████████████████████████████▌ | 49/50 [13:08<00:08,  8.88s/trial, best loss: 5.30692117286708]
# /home/ubuntu/anaconda3/lib/python3.12/site-packages/xgboost/callback.py:386: UserWarning: [12:08:21] WARNING: /workspace/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation-rmse:6.04894
# [1]	validation-rmse:5.60835
# [2]	validation-rmse:5.51883
# [3]	validation-rmse:5.49896
# [4]	validation-rmse:5.49686
# [5]	validation-rmse:5.48705
# [6]	validation-rmse:5.48400
# [7]	validation-rmse:5.48135
# [8]	validation-rmse:5.47219
# [9]	validation-rmse:5.47039
# [10]	validation-rmse:5.45836
# [11]	validation-rmse:5.45781
# [12]	validation-rmse:5.45560
# [13]	validation-rmse:5.45181
# [14]	validation-rmse:5.45067
# [15]	validation-rmse:5.45148
# [16]	validation-rmse:5.45174
# [17]	validation-rmse:5.45263
# [18]	validation-rmse:5.45557
# [19]	validation-rmse:5.45634
# [20]	validation-rmse:5.45397
# [21]	validation-rmse:5.45358
# [22]	validation-rmse:5.45042
# [23]	validation-rmse:5.45358
# [24]	validation-rmse:5.45497
# [25]	validation-rmse:5.45246
# [26]	validation-rmse:5.45142
# [27]	validation-rmse:5.45188
# [28]	validation-rmse:5.45313
# [29]	validation-rmse:5.45563
# [30]	validation-rmse:5.45553
# [31]	validation-rmse:5.45616
# [32]	validation-rmse:5.45658
# [33]	validation-rmse:5.45705
# [34]	validation-rmse:5.45981
# [35]	validation-rmse:5.46056
# [36]	validation-rmse:5.45974
# [37]	validation-rmse:5.46046
# [38]	validation-rmse:5.46070
# [39]	validation-rmse:5.46130
# [40]	validation-rmse:5.46092
# [41]	validation-rmse:5.45820
# [42]	validation-rmse:5.45864
# [43]	validation-rmse:5.45919
# [44]	validation-rmse:5.45968
# [45]	validation-rmse:5.46112
# [46]	validation-rmse:5.46144
# [47]	validation-rmse:5.46215
# [48]	validation-rmse:5.46267
# [49]	validation-rmse:5.46467
# [50]	validation-rmse:5.46608
# [51]	validation-rmse:5.46668
# [52]	validation-rmse:5.46771
# [53]	validation-rmse:5.46968
# [54]	validation-rmse:5.46978
# [55]	validation-rmse:5.47123
# [56]	validation-rmse:5.47112
# [57]	validation-rmse:5.47337
# [58]	validation-rmse:5.47418
# [59]	validation-rmse:5.47470
# [60]	validation-rmse:5.47457
# [61]	validation-rmse:5.47454
# [62]	validation-rmse:5.47593
# [63]	validation-rmse:5.47666
# [64]	validation-rmse:5.48126
# [65]	validation-rmse:5.48279
# [66]	validation-rmse:5.48416
# [67]	validation-rmse:5.48606
# [68]	validation-rmse:5.48691
# [69]	validation-rmse:5.48784
# [70]	validation-rmse:5.48755
# [71]	validation-rmse:5.49078
# 100%|███████████████████████████████████████████████████████████████████████| 50/50 [13:12<00:00, 15.85s/trial, best loss: 5.30692117286708]

# %%
mlflow.xgboost.autolog(disable=True)

# %%
with mlflow.start_run():
    
    train = xgb.DMatrix(X_train, label=y_train)
    valid = xgb.DMatrix(X_val, label=y_val)

    best_params = {
        'learning_rate': 0.09585355369315604,
        'max_depth': 30,
        'min_child_weight': 1.060597050922164,
        'objective': 'reg:linear',
        'reg_alpha': 0.018060244040060163,
        'reg_lambda': 0.011658731377413597,
        'seed': 42
    }

    mlflow.log_params(best_params)

    booster = xgb.train(
        params=best_params,
        dtrain=train,
        num_boost_round=1000,
        evals=[(valid, 'validation')],
        early_stopping_rounds=50
    )

    y_pred = booster.predict(valid)
    rmse = root_mean_squared_error(y_val, y_pred)
    mlflow.log_metric("rmse", rmse)

    with open("models/preprocessor.b", "wb") as f_out:
        pickle.dump(dv, f_out)
    mlflow.log_artifact("models/preprocessor.b", artifact_path="preprocessor")

    mlflow.xgboost.log_model(booster, artifact_path="models_mlflow")
# Out:
# /home/ubuntu/anaconda3/lib/python3.12/site-packages/xgboost/callback.py:386: UserWarning: [12:16:04] WARNING: /workspace/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation-rmse:8.56745
# [1]	validation-rmse:8.10033
# [2]	validation-rmse:7.69739
# [3]	validation-rmse:7.35105
# [4]	validation-rmse:7.05239
# [5]	validation-rmse:6.80020
# [6]	validation-rmse:6.58162
# [7]	validation-rmse:6.39726
# [8]	validation-rmse:6.24197
# [9]	validation-rmse:6.11059
# [10]	validation-rmse:6.00193
# [11]	validation-rmse:5.90700
# [12]	validation-rmse:5.82752
# [13]	validation-rmse:5.76123
# [14]	validation-rmse:5.70306
# [15]	validation-rmse:5.65560
# [16]	validation-rmse:5.61619
# [17]	validation-rmse:5.58065
# [18]	validation-rmse:5.55157
# [19]	validation-rmse:5.52734
# [20]	validation-rmse:5.50858
# [21]	validation-rmse:5.48872
# [22]	validation-rmse:5.47379
# [23]	validation-rmse:5.45957
# [24]	validation-rmse:5.44705
# [25]	validation-rmse:5.43706
# [26]	validation-rmse:5.42713
# [27]	validation-rmse:5.41891
# [28]	validation-rmse:5.41283
# [29]	validation-rmse:5.40819
# [30]	validation-rmse:5.40244
# [31]	validation-rmse:5.39854
# [32]	validation-rmse:5.39446
# [33]	validation-rmse:5.39004
# [34]	validation-rmse:5.38685
# [35]	validation-rmse:5.38264
# [36]	validation-rmse:5.37940
# [37]	validation-rmse:5.37680
# [38]	validation-rmse:5.37557
# [39]	validation-rmse:5.37446
# [40]	validation-rmse:5.37398
# [41]	validation-rmse:5.37311
# [42]	validation-rmse:5.37168
# [43]	validation-rmse:5.37012
# [44]	validation-rmse:5.36946
# [45]	validation-rmse:5.36916
# [46]	validation-rmse:5.36932
# [47]	validation-rmse:5.36798
# [48]	validation-rmse:5.36776
# [49]	validation-rmse:5.36748
# [50]	validation-rmse:5.36663
# [51]	validation-rmse:5.36598
# [52]	validation-rmse:5.36548
# [53]	validation-rmse:5.36492
# [54]	validation-rmse:5.36441
# [55]	validation-rmse:5.36382
# [56]	validation-rmse:5.36376
# [57]	validation-rmse:5.36340
# [58]	validation-rmse:5.36286
# [59]	validation-rmse:5.36263
# [60]	validation-rmse:5.36230
# [61]	validation-rmse:5.36186
# [62]	validation-rmse:5.36140
# [63]	validation-rmse:5.36125
# [64]	validation-rmse:5.36083
# [65]	validation-rmse:5.36025
# [66]	validation-rmse:5.35988
# [67]	validation-rmse:5.35907
# [68]	validation-rmse:5.35877
# [69]	validation-rmse:5.35822
# [70]	validation-rmse:5.35791
# [71]	validation-rmse:5.35767
# [72]	validation-rmse:5.35709
# [73]	validation-rmse:5.35690
# [74]	validation-rmse:5.35643
# [75]	validation-rmse:5.35613
# [76]	validation-rmse:5.35583
# [77]	validation-rmse:5.35571
# [78]	validation-rmse:5.35526
# [79]	validation-rmse:5.35491
# [80]	validation-rmse:5.35478
# [81]	validation-rmse:5.35422
# [82]	validation-rmse:5.35377
# [83]	validation-rmse:5.35366
# [84]	validation-rmse:5.35348
# [85]	validation-rmse:5.35338
# [86]	validation-rmse:5.35268
# [87]	validation-rmse:5.35238
# [88]	validation-rmse:5.35222
# [89]	validation-rmse:5.35207
# [90]	validation-rmse:5.35222
# [91]	validation-rmse:5.35211
# [92]	validation-rmse:5.35171
# [93]	validation-rmse:5.35159
# [94]	validation-rmse:5.35151
# [95]	validation-rmse:5.35146
# [96]	validation-rmse:5.35141
# [97]	validation-rmse:5.35069
# [98]	validation-rmse:5.35048
# [99]	validation-rmse:5.35015
# [100]	validation-rmse:5.35015
# [101]	validation-rmse:5.34987
# [102]	validation-rmse:5.34995
# [103]	validation-rmse:5.34937
# [104]	validation-rmse:5.34942
# [105]	validation-rmse:5.34926
# [106]	validation-rmse:5.34906
# [107]	validation-rmse:5.34844
# [108]	validation-rmse:5.34842
# [109]	validation-rmse:5.34862
# [110]	validation-rmse:5.34826
# [111]	validation-rmse:5.34813
# [112]	validation-rmse:5.34771
# [113]	validation-rmse:5.34770
# [114]	validation-rmse:5.34757
# [115]	validation-rmse:5.34715
# [116]	validation-rmse:5.34679
# [117]	validation-rmse:5.34671
# [118]	validation-rmse:5.34628
# [119]	validation-rmse:5.34616
# [120]	validation-rmse:5.34638
# [121]	validation-rmse:5.34591
# [122]	validation-rmse:5.34571
# [123]	validation-rmse:5.34564
# [124]	validation-rmse:5.34567
# [125]	validation-rmse:5.34552
# [126]	validation-rmse:5.34560
# [127]	validation-rmse:5.34526
# [128]	validation-rmse:5.34533
# [129]	validation-rmse:5.34547
# [130]	validation-rmse:5.34589
# [131]	validation-rmse:5.34586
# [132]	validation-rmse:5.34585
# [133]	validation-rmse:5.34582
# [134]	validation-rmse:5.34554
# [135]	validation-rmse:5.34515
# [136]	validation-rmse:5.34497
# [137]	validation-rmse:5.34456
# [138]	validation-rmse:5.34441
# [139]	validation-rmse:5.34410
# [140]	validation-rmse:5.34386
# [141]	validation-rmse:5.34372
# [142]	validation-rmse:5.34336
# [143]	validation-rmse:5.34309
# [144]	validation-rmse:5.34328
# [145]	validation-rmse:5.34308
# [146]	validation-rmse:5.34319
# [147]	validation-rmse:5.34327
# [148]	validation-rmse:5.34311
# [149]	validation-rmse:5.34286
# [150]	validation-rmse:5.34270
# [151]	validation-rmse:5.34285
# [152]	validation-rmse:5.34294
# [153]	validation-rmse:5.34280
# [154]	validation-rmse:5.34289
# [155]	validation-rmse:5.34278
# [156]	validation-rmse:5.34263
# [157]	validation-rmse:5.34208
# [158]	validation-rmse:5.34212
# [159]	validation-rmse:5.34266
# [160]	validation-rmse:5.34248
# [161]	validation-rmse:5.34240
# [162]	validation-rmse:5.34237
# [163]	validation-rmse:5.34236
# [164]	validation-rmse:5.34202
# [165]	validation-rmse:5.34197
# [166]	validation-rmse:5.34191
# [167]	validation-rmse:5.34147
# [168]	validation-rmse:5.34132
# [169]	validation-rmse:5.34079
# [170]	validation-rmse:5.34038
# [171]	validation-rmse:5.34056
# [172]	validation-rmse:5.34046
# [173]	validation-rmse:5.34030
# [174]	validation-rmse:5.34022
# [175]	validation-rmse:5.34033
# [176]	validation-rmse:5.34043
# [177]	validation-rmse:5.34047
# [178]	validation-rmse:5.34036
# [179]	validation-rmse:5.34031
# [180]	validation-rmse:5.34035
# [181]	validation-rmse:5.34027
# [182]	validation-rmse:5.34003
# [183]	validation-rmse:5.34007
# [184]	validation-rmse:5.34005
# [185]	validation-rmse:5.34004
# [186]	validation-rmse:5.34000
# [187]	validation-rmse:5.34006
# [188]	validation-rmse:5.33954
# [189]	validation-rmse:5.33955
# [190]	validation-rmse:5.33951
# [191]	validation-rmse:5.33999
# [192]	validation-rmse:5.33981
# [193]	validation-rmse:5.33976
# [194]	validation-rmse:5.33882
# [195]	validation-rmse:5.33889
# [196]	validation-rmse:5.33881
# [197]	validation-rmse:5.33905
# [198]	validation-rmse:5.33890
# [199]	validation-rmse:5.33890
# [200]	validation-rmse:5.33859
# [201]	validation-rmse:5.33850
# [202]	validation-rmse:5.33840
# [203]	validation-rmse:5.33835
# [204]	validation-rmse:5.33823
# [205]	validation-rmse:5.33811
# [206]	validation-rmse:5.33777
# [207]	validation-rmse:5.33786
# [208]	validation-rmse:5.33761
# [209]	validation-rmse:5.33761
# [210]	validation-rmse:5.33793
# [211]	validation-rmse:5.33798
# [212]	validation-rmse:5.33743
# [213]	validation-rmse:5.33743
# [214]	validation-rmse:5.33731
# [215]	validation-rmse:5.33718
# [216]	validation-rmse:5.33719
# [217]	validation-rmse:5.33668
# [218]	validation-rmse:5.33681
# [219]	validation-rmse:5.33712
# [220]	validation-rmse:5.33734
# [221]	validation-rmse:5.33729
# [222]	validation-rmse:5.33712
# [223]	validation-rmse:5.33679
# [224]	validation-rmse:5.33697
# [225]	validation-rmse:5.33714
# [226]	validation-rmse:5.33713
# [227]	validation-rmse:5.33691
# [228]	validation-rmse:5.33746
# [229]	validation-rmse:5.33729
# [230]	validation-rmse:5.33729
# [231]	validation-rmse:5.33753
# [232]	validation-rmse:5.33734
# [233]	validation-rmse:5.33738
# [234]	validation-rmse:5.33728
# [235]	validation-rmse:5.33677
# [236]	validation-rmse:5.33669
# [237]	validation-rmse:5.33656
# [238]	validation-rmse:5.33640
# [239]	validation-rmse:5.33635
# [240]	validation-rmse:5.33635
# [241]	validation-rmse:5.33629
# [242]	validation-rmse:5.33638
# [243]	validation-rmse:5.33624
# [244]	validation-rmse:5.33618
# [245]	validation-rmse:5.33614
# [246]	validation-rmse:5.33620
# [247]	validation-rmse:5.33627
# [248]	validation-rmse:5.33648
# [249]	validation-rmse:5.33637
# [250]	validation-rmse:5.33636
# [251]	validation-rmse:5.33654
# [252]	validation-rmse:5.33618
# [253]	validation-rmse:5.33602
# [254]	validation-rmse:5.33590
# [255]	validation-rmse:5.33598
# [256]	validation-rmse:5.33599
# [257]	validation-rmse:5.33629
# [258]	validation-rmse:5.33624
# [259]	validation-rmse:5.33612
# [260]	validation-rmse:5.33578
# [261]	validation-rmse:5.33573
# [262]	validation-rmse:5.33566
# [263]	validation-rmse:5.33545
# [264]	validation-rmse:5.33544
# [265]	validation-rmse:5.33512
# [266]	validation-rmse:5.33510
# [267]	validation-rmse:5.33555
# [268]	validation-rmse:5.33545
# [269]	validation-rmse:5.33556
# [270]	validation-rmse:5.33573
# [271]	validation-rmse:5.33591
# [272]	validation-rmse:5.33584
# [273]	validation-rmse:5.33583
# [274]	validation-rmse:5.33602
# [275]	validation-rmse:5.33597
# [276]	validation-rmse:5.33591
# [277]	validation-rmse:5.33575
# [278]	validation-rmse:5.33568
# [279]	validation-rmse:5.33572
# [280]	validation-rmse:5.33570
# [281]	validation-rmse:5.33554
# [282]	validation-rmse:5.33537
# [283]	validation-rmse:5.33531
# [284]	validation-rmse:5.33536
# [285]	validation-rmse:5.33531
# [286]	validation-rmse:5.33541
# [287]	validation-rmse:5.33539
# [288]	validation-rmse:5.33537
# [289]	validation-rmse:5.33528
# [290]	validation-rmse:5.33539
# [291]	validation-rmse:5.33483
# [292]	validation-rmse:5.33475
# [293]	validation-rmse:5.33480
# [294]	validation-rmse:5.33458
# [295]	validation-rmse:5.33477
# [296]	validation-rmse:5.33462
# [297]	validation-rmse:5.33469
# [298]	validation-rmse:5.33478
# [299]	validation-rmse:5.33485
# [300]	validation-rmse:5.33458
# [301]	validation-rmse:5.33453
# [302]	validation-rmse:5.33443
# [303]	validation-rmse:5.33475
# [304]	validation-rmse:5.33405
# [305]	validation-rmse:5.33353
# [306]	validation-rmse:5.33366
# [307]	validation-rmse:5.33370
# [308]	validation-rmse:5.33348
# [309]	validation-rmse:5.33350
# [310]	validation-rmse:5.33354
# [311]	validation-rmse:5.33355
# [312]	validation-rmse:5.33347
# [313]	validation-rmse:5.33341
# [314]	validation-rmse:5.33353
# [315]	validation-rmse:5.33342
# [316]	validation-rmse:5.33373
# [317]	validation-rmse:5.33379
# [318]	validation-rmse:5.33379
# [319]	validation-rmse:5.33399
# [320]	validation-rmse:5.33397
# [321]	validation-rmse:5.33379
# [322]	validation-rmse:5.33392
# [323]	validation-rmse:5.33405
# [324]	validation-rmse:5.33362
# [325]	validation-rmse:5.33359
# [326]	validation-rmse:5.33349
# [327]	validation-rmse:5.33350
# [328]	validation-rmse:5.33315
# [329]	validation-rmse:5.33313
# [330]	validation-rmse:5.33317
# [331]	validation-rmse:5.33312
# [332]	validation-rmse:5.33309
# [333]	validation-rmse:5.33308
# [334]	validation-rmse:5.33320
# [335]	validation-rmse:5.33330
# [336]	validation-rmse:5.33314
# [337]	validation-rmse:5.33318
# [338]	validation-rmse:5.33324
# [339]	validation-rmse:5.33334
# [340]	validation-rmse:5.33354
# [341]	validation-rmse:5.33333
# [342]	validation-rmse:5.33329
# [343]	validation-rmse:5.33340
# [344]	validation-rmse:5.33338
# [345]	validation-rmse:5.33321
# [346]	validation-rmse:5.33328
# [347]	validation-rmse:5.33333
# [348]	validation-rmse:5.33332
# [349]	validation-rmse:5.33337
# [350]	validation-rmse:5.33348
# [351]	validation-rmse:5.33357
# [352]	validation-rmse:5.33359
# [353]	validation-rmse:5.33353
# [354]	validation-rmse:5.33357
# [355]	validation-rmse:5.33321
# [356]	validation-rmse:5.33319
# [357]	validation-rmse:5.33314
# [358]	validation-rmse:5.33290
# [359]	validation-rmse:5.33272
# [360]	validation-rmse:5.33304
# [361]	validation-rmse:5.33315
# [362]	validation-rmse:5.33318
# [363]	validation-rmse:5.33273
# [364]	validation-rmse:5.33241
# [365]	validation-rmse:5.33242
# [366]	validation-rmse:5.33232
# [367]	validation-rmse:5.33228
# [368]	validation-rmse:5.33255
# [369]	validation-rmse:5.33236
# [370]	validation-rmse:5.33238
# [371]	validation-rmse:5.33234
# [372]	validation-rmse:5.33199
# [373]	validation-rmse:5.33193
# [374]	validation-rmse:5.33208
# [375]	validation-rmse:5.33196
# [376]	validation-rmse:5.33201
# [377]	validation-rmse:5.33204
# [378]	validation-rmse:5.33197
# [379]	validation-rmse:5.33231
# [380]	validation-rmse:5.33213
# [381]	validation-rmse:5.33225
# [382]	validation-rmse:5.33220
# [383]	validation-rmse:5.33225
# [384]	validation-rmse:5.33211
# [385]	validation-rmse:5.33204
# [386]	validation-rmse:5.33241
# [387]	validation-rmse:5.33229
# [388]	validation-rmse:5.33231
# [389]	validation-rmse:5.33241
# [390]	validation-rmse:5.33258
# [391]	validation-rmse:5.33259
# [392]	validation-rmse:5.33257
# [393]	validation-rmse:5.33247
# [394]	validation-rmse:5.33250
# [395]	validation-rmse:5.33243
# [396]	validation-rmse:5.33245
# [397]	validation-rmse:5.33261
# [398]	validation-rmse:5.33269
# [399]	validation-rmse:5.33270
# [400]	validation-rmse:5.33283
# [401]	validation-rmse:5.33283
# [402]	validation-rmse:5.33225
# [403]	validation-rmse:5.33197
# [404]	validation-rmse:5.33190
# [405]	validation-rmse:5.33193
# [406]	validation-rmse:5.33188
# [407]	validation-rmse:5.33202
# [408]	validation-rmse:5.33199
# [409]	validation-rmse:5.33188
# [410]	validation-rmse:5.33189
# [411]	validation-rmse:5.33169
# [412]	validation-rmse:5.33173
# [413]	validation-rmse:5.33173
# [414]	validation-rmse:5.33172
# [415]	validation-rmse:5.33178
# [416]	validation-rmse:5.33178
# [417]	validation-rmse:5.33178
# [418]	validation-rmse:5.33173
# [419]	validation-rmse:5.33169
# [420]	validation-rmse:5.33183
# [421]	validation-rmse:5.33171
# [422]	validation-rmse:5.33182
# [423]	validation-rmse:5.33171
# [424]	validation-rmse:5.33162
# [425]	validation-rmse:5.33166
# [426]	validation-rmse:5.33168
# [427]	validation-rmse:5.33146
# [428]	validation-rmse:5.33143
# [429]	validation-rmse:5.33149
# [430]	validation-rmse:5.33213
# [431]	validation-rmse:5.33221
# [432]	validation-rmse:5.33237
# [433]	validation-rmse:5.33238
# [434]	validation-rmse:5.33258
# [435]	validation-rmse:5.33238
# [436]	validation-rmse:5.33236
# [437]	validation-rmse:5.33224
# [438]	validation-rmse:5.33213
# [439]	validation-rmse:5.33212
# [440]	validation-rmse:5.33211
# [441]	validation-rmse:5.33214
# [442]	validation-rmse:5.33201
# [443]	validation-rmse:5.33213
# [444]	validation-rmse:5.33212
# [445]	validation-rmse:5.33210
# [446]	validation-rmse:5.33216
# [447]	validation-rmse:5.33209
# [448]	validation-rmse:5.33211
# [449]	validation-rmse:5.33234
# [450]	validation-rmse:5.33231
# [451]	validation-rmse:5.33245
# [452]	validation-rmse:5.33252
# [453]	validation-rmse:5.33237
# [454]	validation-rmse:5.33225
# [455]	validation-rmse:5.33230
# [456]	validation-rmse:5.33250
# [457]	validation-rmse:5.33241
# [458]	validation-rmse:5.33236
# [459]	validation-rmse:5.33241
# [460]	validation-rmse:5.33240
# [461]	validation-rmse:5.33263
# [462]	validation-rmse:5.33293
# [463]	validation-rmse:5.33315
# [464]	validation-rmse:5.33312
# [465]	validation-rmse:5.33279
# [466]	validation-rmse:5.33290
# [467]	validation-rmse:5.33316
# [468]	validation-rmse:5.33325
# [469]	validation-rmse:5.33322
# [470]	validation-rmse:5.33338
# [471]	validation-rmse:5.33314
# [472]	validation-rmse:5.33317
# [473]	validation-rmse:5.33329
# [474]	validation-rmse:5.33330
# [475]	validation-rmse:5.33336
# [476]	validation-rmse:5.33336
# [477]	validation-rmse:5.33326
# /home/ubuntu/anaconda3/lib/python3.12/site-packages/mlflow/xgboost/__init__.py:168: UserWarning: [12:16:23] WARNING: /workspace/src/c_api/c_api.cc:1427: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats.
#   xgb_model.save_model(model_data_path)
# 2025/05/25 12:16:29 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.

# %%
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor
from sklearn.svm import LinearSVR

mlflow.sklearn.autolog()

for model_class in (RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor, LinearSVR):

    with mlflow.start_run():

        mlflow.log_param("train-data-path", "./data/green_tripdata_2021-01.csv")
        mlflow.log_param("valid-data-path", "./data/green_tripdata_2021-02.csv")
        mlflow.log_artifact("models/preprocessor.b", artifact_path="preprocessor")

        mlmodel = model_class()
        mlmodel.fit(X_train, y_train)

        y_pred = mlmodel.predict(X_val)
        rmse = root_mean_squared_error(y_val, y_pred)
        mlflow.log_metric("rmse", rmse)
# Out:
# /home/ubuntu/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1235: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
