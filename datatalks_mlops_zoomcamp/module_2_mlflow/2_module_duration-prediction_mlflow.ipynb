# %%
# !python -V
# Out:
# Python 3.13.2

# %% [markdown]
# # Run MLFlow service with Sqlite backend

# %%
# !mlflow ui --backend-store-uri sqlite:///mlflow.db
# Out:
#   Cell In[2], line 1
#     mlflow ui --backend-store-uri sqlite:///mlflow.db
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Import and Setup MLFlow library

# %%
import mlflow

mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("mlops-experiment")
# Out:
# <Experiment: artifact_location='/Users/sstamkulov/Documents/ml/jupyter_notebooks_archive/datatalks_ml_zoomcamp/module_2_mlflow/mlruns/1', creation_time=1748153971145, experiment_id='1', last_update_time=1748153971145, lifecycle_stage='active', name='mlops-experiment', tags={}>

# %% [markdown]
# # Train and Evaluate model

# %%
import pandas as pd

# %%
import pickle

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge

from sklearn.metrics import root_mean_squared_error

# %%
def read_dataframe(filename):
    df = pd.read_parquet(filename)

    df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
    df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)

    df['duration'] = df.lpep_dropoff_datetime - df.lpep_pickup_datetime
    df.duration = df.duration.apply(lambda td: td.total_seconds() / 60)

    df = df[(df.duration >= 1) & (df.duration <= 60)]

    categorical = ['PULocationID', 'DOLocationID']
    df[categorical] = df[categorical].astype(str)
    
    return df

# %%
train_file = '../data/green_tripdata_2025-01.parquet'
val_file = '../data/green_tripdata_2025-02.parquet'

df_train = read_dataframe(train_file)
df_val = read_dataframe(val_file)

# %%
len(df_train), len(df_val)
# Out:
# (46307, 44218)

# %%
df_train['PU_DO'] = df_train['PULocationID'] + '_' + df_train['DOLocationID']
df_val['PU_DO'] = df_val['PULocationID'] + '_' + df_val['DOLocationID']

# %%
categorical = ['PU_DO'] #'PULocationID', 'DOLocationID']
numerical = ['trip_distance']

dv = DictVectorizer()

train_dicts = df_train[categorical + numerical].to_dict(orient='records')
X_train = dv.fit_transform(train_dicts)

val_dicts = df_val[categorical + numerical].to_dict(orient='records')
X_val = dv.transform(val_dicts)

# %%
target = 'duration'
y_train = df_train[target].values
y_val = df_val[target].values

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_val)

root_mean_squared_error(y_val, y_pred)
# Out:
# 6.098871741054109

# %%
with open('models/lin_reg.bin', 'wb') as f_out:
    pickle.dump((dv, lr), f_out)

# %%
with mlflow.start_run():

    mlflow.set_tag("developer", "cristian")

    mlflow.log_param("train-data-path", train_file)
    mlflow.log_param("valid-data-path", val_file)

    alpha = 0.1
    mlflow.log_param("alpha", alpha)
    lr = Lasso(alpha)
    lr.fit(X_train, y_train)

    y_pred = lr.predict(X_val)
    rmse = root_mean_squared_error(y_val, y_pred)
    mlflow.log_metric("rmse", rmse)

    mlflow.log_artifact(local_path="models/lin_reg.bin", artifact_path="models_pickle")

# %%
import xgboost as xgb

# %%
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope

# %%
train = xgb.DMatrix(X_train, label=y_train)
valid = xgb.DMatrix(X_val, label=y_val)

# %%
def objective(params):
    with mlflow.start_run():
        mlflow.set_tag("model", "xgboost")
        mlflow.log_params(params)
        booster = xgb.train(
            params=params,
            dtrain=train,
            num_boost_round=1000,
            evals=[(valid, 'validation')],
            early_stopping_rounds=50
        )
        y_pred = booster.predict(valid)
        rmse = root_mean_squared_error(y_val, y_pred)
        mlflow.log_metric("rmse", rmse)

    return {'loss': rmse, 'status': STATUS_OK}

# %%
search_space = {
    'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
    'learning_rate': hp.loguniform('learning_rate', -3, 0),
    'reg_alpha': hp.loguniform('reg_alpha', -5, -1),
    'reg_lambda': hp.loguniform('reg_lambda', -6, -1),
    'min_child_weight': hp.loguniform('min_child_weight', -1, 3),
    'objective': 'reg:linear',
    'seed': 42
}

best_result = fmin(
    fn=objective,
    space=search_space,
    algo=tpe.suggest,
    max_evals=50,
    trials=Trials()
)
# Out:
# [0]	validation-rmse:7.36228
#   0%|          | 0/50 [00:00<?, ?trial/s, best loss=?]
# /opt/anaconda3/envs/ml/lib/python3.13/site-packages/xgboost/callback.py:386: UserWarning: [08:29:49] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   self.starting_round = model.num_boosted_rounds()
# [1]	validation-rmse:6.42930
# [2]	validation-rmse:5.96119
# [3]	validation-rmse:5.72710
# [4]	validation-rmse:5.60752
# [5]	validation-rmse:5.54008
# [6]	validation-rmse:5.51165
# [7]	validation-rmse:5.49392
# [8]	validation-rmse:5.48451
# [9]	validation-rmse:5.47454
# [10]	validation-rmse:5.46993
# [11]	validation-rmse:5.46716
# [12]	validation-rmse:5.46599
# [13]	validation-rmse:5.46557
# [14]	validation-rmse:5.46580
# [15]	validation-rmse:5.46457
# [16]	validation-rmse:5.46440
# [17]	validation-rmse:5.46204
# [18]	validation-rmse:5.46064
# [19]	validation-rmse:5.46063
# [20]	validation-rmse:5.46114
# [21]	validation-rmse:5.45659
# [22]	validation-rmse:5.45434
# [23]	validation-rmse:5.45385
# [24]	validation-rmse:5.45145
# [25]	validation-rmse:5.45232
# [26]	validation-rmse:5.45118
# [27]	validation-rmse:5.45081
# [28]	validation-rmse:5.44992
# [29]	validation-rmse:5.44888
# [30]	validation-rmse:5.44612
# [31]	validation-rmse:5.44590
# [32]	validation-rmse:5.44588
# [33]	validation-rmse:5.44534
# [34]	validation-rmse:5.44515
# [35]	validation-rmse:5.44651
# [36]	validation-rmse:5.44378
# [37]	validation-rmse:5.44411
# [38]	validation-rmse:5.44400
# [39]	validation-rmse:5.44489
# [40]	validation-rmse:5.44406
# [41]	validation-rmse:5.44434
# [42]	validation-rmse:5.44288
# [43]	validation-rmse:5.44271
# [44]	validation-rmse:5.44219
# [45]	validation-rmse:5.44273
# [46]	validation-rmse:5.44264
# [47]	validation-rmse:5.44239
# [48]	validation-rmse:5.44257
# [49]	validation-rmse:5.44256
# [50]	validation-rmse:5.44290
# [51]	validation-rmse:5.44339
# [52]	validation-rmse:5.44304
# [53]	validation-rmse:5.44309
# [54]	validation-rmse:5.44318
# [55]	validation-rmse:5.44224
# [56]	validation-rmse:5.43847
# [57]	validation-rmse:5.43883
# [58]	validation-rmse:5.43795
# [59]	validation-rmse:5.43822
# [60]	validation-rmse:5.43830
# [61]	validation-rmse:5.43894
# [62]	validation-rmse:5.43943
# [63]	validation-rmse:5.43974
# [64]	validation-rmse:5.44011
# [65]	validation-rmse:5.44086
# [66]	validation-rmse:5.44069
# [67]	validation-rmse:5.44002
# [68]	validation-rmse:5.44008
# [69]	validation-rmse:5.44091
# [70]	validation-rmse:5.44076
# [71]	validation-rmse:5.44068
# [72]	validation-rmse:5.44044
# [73]	validation-rmse:5.44087
# [74]	validation-rmse:5.44208
# [75]	validation-rmse:5.44137
# [76]	validation-rmse:5.44141
# [77]	validation-rmse:5.44151
# [78]	validation-rmse:5.44177
# [79]	validation-rmse:5.44117
# [80]	validation-rmse:5.44172
# [81]	validation-rmse:5.44196
# [82]	validation-rmse:5.44212
# [83]	validation-rmse:5.44287
# [84]	validation-rmse:5.44351
# [85]	validation-rmse:5.44325
# [86]	validation-rmse:5.44205
# [87]	validation-rmse:5.44173
# [88]	validation-rmse:5.44151
# [89]	validation-rmse:5.44332
# [90]	validation-rmse:5.44436
# [91]	validation-rmse:5.44472
# [92]	validation-rmse:5.44598
# [93]	validation-rmse:5.44574
# [94]	validation-rmse:5.44599
# [95]	validation-rmse:5.44624
# [96]	validation-rmse:5.44713
# [97]	validation-rmse:5.44700
# [98]	validation-rmse:5.44751
# [99]	validation-rmse:5.44744
# [100]	validation-rmse:5.44804
# [101]	validation-rmse:5.44855
# [102]	validation-rmse:5.44894
# [103]	validation-rmse:5.44914
# [104]	validation-rmse:5.44928
# [105]	validation-rmse:5.44958
# [106]	validation-rmse:5.44873
# [107]	validation-rmse:5.44885
# [0]	validation-rmse:8.31535
#   2%|▏         | 1/50 [00:03<02:46,  3.40s/trial, best loss: 5.449612700046095]
# /opt/anaconda3/envs/ml/lib/python3.13/site-packages/xgboost/callback.py:386: UserWarning: [08:29:52] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   self.starting_round = model.num_boosted_rounds()
# [1]	validation-rmse:7.67639
# [2]	validation-rmse:7.16716
# [3]	validation-rmse:6.76328
# [4]	validation-rmse:6.44801
# [5]	validation-rmse:6.20255
# [6]	validation-rmse:6.01144
# [7]	validation-rmse:5.86590
# [8]	validation-rmse:5.75407
# [9]	validation-rmse:5.66970
# [10]	validation-rmse:5.60485
# [11]	validation-rmse:5.55757
# [12]	validation-rmse:5.52099
# [13]	validation-rmse:5.49167
# [14]	validation-rmse:5.46819
# [15]	validation-rmse:5.45155
# [16]	validation-rmse:5.43978
# [17]	validation-rmse:5.42909
# [18]	validation-rmse:5.42136
# [19]	validation-rmse:5.41446
# [20]	validation-rmse:5.40961
# [21]	validation-rmse:5.40297
# [22]	validation-rmse:5.39793
# [23]	validation-rmse:5.39490
# [24]	validation-rmse:5.39207
# [25]	validation-rmse:5.38954
# [26]	validation-rmse:5.38748
# [27]	validation-rmse:5.38567
# [28]	validation-rmse:5.38456
# [29]	validation-rmse:5.38289
# [30]	validation-rmse:5.38253
# [31]	validation-rmse:5.38186
# [32]	validation-rmse:5.38107
# [33]	validation-rmse:5.38073
# [34]	validation-rmse:5.37767
# [35]	validation-rmse:5.37464
# [36]	validation-rmse:5.37264
# [37]	validation-rmse:5.37123
# [38]	validation-rmse:5.37034
# [39]	validation-rmse:5.36735
# [40]	validation-rmse:5.36703
# [41]	validation-rmse:5.36556
# [42]	validation-rmse:5.36568
# [43]	validation-rmse:5.36584
# [44]	validation-rmse:5.36528
# [45]	validation-rmse:5.36462
# [46]	validation-rmse:5.36400
# [47]	validation-rmse:5.36374
# [48]	validation-rmse:5.36350
# [49]	validation-rmse:5.36326
# [50]	validation-rmse:5.36319
# [51]	validation-rmse:5.36288
# [52]	validation-rmse:5.36301
# [53]	validation-rmse:5.36210
# [54]	validation-rmse:5.36230
# [55]	validation-rmse:5.36110
# [56]	validation-rmse:5.36084
# [57]	validation-rmse:5.36097
# [58]	validation-rmse:5.36089
# [59]	validation-rmse:5.36088
# [60]	validation-rmse:5.36111
# [61]	validation-rmse:5.36109
# [62]	validation-rmse:5.36090
# [63]	validation-rmse:5.36076
# [64]	validation-rmse:5.36033
# [65]	validation-rmse:5.36053
# [66]	validation-rmse:5.36015
# [67]	validation-rmse:5.35980
# [68]	validation-rmse:5.35991
# [69]	validation-rmse:5.35968
# [70]	validation-rmse:5.35905
# [71]	validation-rmse:5.35889
# [72]	validation-rmse:5.35872
# [73]	validation-rmse:5.35825
# [74]	validation-rmse:5.35859
# [75]	validation-rmse:5.35862
# [76]	validation-rmse:5.35883
# [77]	validation-rmse:5.35892
# [78]	validation-rmse:5.35855
# [79]	validation-rmse:5.35857
# [80]	validation-rmse:5.35803
# [81]	validation-rmse:5.35833
# [82]	validation-rmse:5.35854
# [83]	validation-rmse:5.35809
# [84]	validation-rmse:5.35760
# [85]	validation-rmse:5.35703
# [86]	validation-rmse:5.35708
# [87]	validation-rmse:5.35722
# [88]	validation-rmse:5.35709
# [89]	validation-rmse:5.35679
# [90]	validation-rmse:5.35658
# [91]	validation-rmse:5.35641
# [92]	validation-rmse:5.35601
# [93]	validation-rmse:5.35575
# [94]	validation-rmse:5.35575
# [95]	validation-rmse:5.35605
# [96]	validation-rmse:5.35592
# [97]	validation-rmse:5.35606
# [98]	validation-rmse:5.35607
# [99]	validation-rmse:5.35623
# [100]	validation-rmse:5.35634
# [101]	validation-rmse:5.35629
# [102]	validation-rmse:5.35623
# [103]	validation-rmse:5.35626
# [104]	validation-rmse:5.35629
# [105]	validation-rmse:5.35640
# [106]	validation-rmse:5.35639
# [107]	validation-rmse:5.35604
# [108]	validation-rmse:5.35592
# [109]	validation-rmse:5.35585
# [110]	validation-rmse:5.35578
# [111]	validation-rmse:5.35550
# [112]	validation-rmse:5.35527
# [113]	validation-rmse:5.35554
# [114]	validation-rmse:5.35533
# [115]	validation-rmse:5.35533
# [116]	validation-rmse:5.35511
# [117]	validation-rmse:5.35531
# [118]	validation-rmse:5.35535
# [119]	validation-rmse:5.35493
# [120]	validation-rmse:5.35503
# [121]	validation-rmse:5.35496
# [122]	validation-rmse:5.35444
# [123]	validation-rmse:5.35422
# [124]	validation-rmse:5.35430
# [125]	validation-rmse:5.35413
# [126]	validation-rmse:5.35420
# [127]	validation-rmse:5.35417
# [128]	validation-rmse:5.35395
# [129]	validation-rmse:5.35417
# [130]	validation-rmse:5.35421
# [131]	validation-rmse:5.35415
# [132]	validation-rmse:5.35426
# [133]	validation-rmse:5.35441
# [134]	validation-rmse:5.35433
# [135]	validation-rmse:5.35414
# [136]	validation-rmse:5.35425
# [137]	validation-rmse:5.35463
# [138]	validation-rmse:5.35454
# [139]	validation-rmse:5.35468
# [140]	validation-rmse:5.35496
# [141]	validation-rmse:5.35499
# [142]	validation-rmse:5.35550
# [143]	validation-rmse:5.35539
# [144]	validation-rmse:5.35496
# [145]	validation-rmse:5.35516
# [146]	validation-rmse:5.35523
# [147]	validation-rmse:5.35509
# [148]	validation-rmse:5.35522
# [149]	validation-rmse:5.35501
# [150]	validation-rmse:5.35528
# [151]	validation-rmse:5.35527
# [152]	validation-rmse:5.35515
# [153]	validation-rmse:5.35508
# [154]	validation-rmse:5.35476
# [155]	validation-rmse:5.35483
# [156]	validation-rmse:5.35477
# [157]	validation-rmse:5.35488
# [158]	validation-rmse:5.35472
# [159]	validation-rmse:5.35474
# [160]	validation-rmse:5.35449
# [161]	validation-rmse:5.35478
# [162]	validation-rmse:5.35480
# [163]	validation-rmse:5.35491
# [164]	validation-rmse:5.35489
# [165]	validation-rmse:5.35481
# [166]	validation-rmse:5.35464
# [167]	validation-rmse:5.35501
# [168]	validation-rmse:5.35487
# [169]	validation-rmse:5.35520
# [170]	validation-rmse:5.35504
# [171]	validation-rmse:5.35529
# [172]	validation-rmse:5.35533
# [173]	validation-rmse:5.35527
# [174]	validation-rmse:5.35540
# [175]	validation-rmse:5.35527
# [176]	validation-rmse:5.35529
# [177]	validation-rmse:5.35548
# [178]	validation-rmse:5.35549
# [0]	validation-rmse:8.67497
#   4%|▍         | 2/50 [00:13<05:36,  7.01s/trial, best loss: 5.355485737486048]
# /opt/anaconda3/envs/ml/lib/python3.13/site-packages/xgboost/callback.py:386: UserWarning: [08:30:01] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   self.starting_round = model.num_boosted_rounds()
# [1]	validation-rmse:8.28902
# [2]	validation-rmse:7.94321
# [3]	validation-rmse:7.63595
# [4]	validation-rmse:7.36260
# [5]	validation-rmse:7.12000
# [6]	validation-rmse:6.90360
# [7]	validation-rmse:6.71418
# [8]	validation-rmse:6.54728
# [9]	validation-rmse:6.40048
# [10]	validation-rmse:6.27141
# [11]	validation-rmse:6.15754
# [12]	validation-rmse:6.05845
# [13]	validation-rmse:5.97110
# [14]	validation-rmse:5.89445
# [15]	validation-rmse:5.82921
# [16]	validation-rmse:5.77050
# [17]	validation-rmse:5.71807
# [18]	validation-rmse:5.67393
# [19]	validation-rmse:5.63565
# [20]	validation-rmse:5.60188
# [21]	validation-rmse:5.57236
# [22]	validation-rmse:5.54837
# [23]	validation-rmse:5.52635
# [24]	validation-rmse:5.50671
# [25]	validation-rmse:5.48839
# [26]	validation-rmse:5.47335
# [27]	validation-rmse:5.46014
# [28]	validation-rmse:5.44846
# [29]	validation-rmse:5.43672
# [30]	validation-rmse:5.42609
# [31]	validation-rmse:5.41711
# [32]	validation-rmse:5.40978
# [33]	validation-rmse:5.40352
# [34]	validation-rmse:5.39760
# [35]	validation-rmse:5.39201
# [36]	validation-rmse:5.38656
# [37]	validation-rmse:5.38259
# [38]	validation-rmse:5.37922
# [39]	validation-rmse:5.37493
# [40]	validation-rmse:5.37146
# [41]	validation-rmse:5.36880
# [42]	validation-rmse:5.36602
# [43]	validation-rmse:5.36372
# [44]	validation-rmse:5.36145
# [45]	validation-rmse:5.36069
# [46]	validation-rmse:5.35897
# [47]	validation-rmse:5.35720
# [48]	validation-rmse:5.35651
# [49]	validation-rmse:5.35549
# [50]	validation-rmse:5.35422
# [51]	validation-rmse:5.35344
# [52]	validation-rmse:5.35235
# [53]	validation-rmse:5.35175
# [54]	validation-rmse:5.35147
# [55]	validation-rmse:5.35044
# [56]	validation-rmse:5.35016
# [57]	validation-rmse:5.34966
# [58]	validation-rmse:5.34900
# [59]	validation-rmse:5.34869
# [60]	validation-rmse:5.34853
# [61]	validation-rmse:5.34838
# [62]	validation-rmse:5.34815
# [63]	validation-rmse:5.34787
# [64]	validation-rmse:5.34770
# [65]	validation-rmse:5.34771
# [66]	validation-rmse:5.34760
# [67]	validation-rmse:5.34766
# [68]	validation-rmse:5.34744
# [69]	validation-rmse:5.34731
# [70]	validation-rmse:5.34732
# [71]	validation-rmse:5.34722
# [72]	validation-rmse:5.34705
# [73]	validation-rmse:5.34709
# [74]	validation-rmse:5.34727
# [75]	validation-rmse:5.34719
# [76]	validation-rmse:5.34752
# [77]	validation-rmse:5.34725
# [78]	validation-rmse:5.34715
# [79]	validation-rmse:5.34720
# [80]	validation-rmse:5.34691
# [81]	validation-rmse:5.34693
# [82]	validation-rmse:5.34674
# [83]	validation-rmse:5.34668
# [84]	validation-rmse:5.34630
# [85]	validation-rmse:5.34632
# [86]	validation-rmse:5.34619
# [87]	validation-rmse:5.34564
# [88]	validation-rmse:5.34568
# [89]	validation-rmse:5.34530
# [90]	validation-rmse:5.34508
# [91]	validation-rmse:5.34475
# [92]	validation-rmse:5.34487
# [93]	validation-rmse:5.34517
# [94]	validation-rmse:5.34489
# [95]	validation-rmse:5.34489
# [96]	validation-rmse:5.34504
# [97]	validation-rmse:5.34491
# [98]	validation-rmse:5.34490
# [99]	validation-rmse:5.34486
# [100]	validation-rmse:5.34491
# [101]	validation-rmse:5.34499
# [102]	validation-rmse:5.34490
# [103]	validation-rmse:5.34464
# [104]	validation-rmse:5.34457
# [105]	validation-rmse:5.34433
# [106]	validation-rmse:5.34426
# [107]	validation-rmse:5.34429
# [108]	validation-rmse:5.34409
# [109]	validation-rmse:5.34408
# [110]	validation-rmse:5.34417
# [111]	validation-rmse:5.34409
# [112]	validation-rmse:5.34399
# [113]	validation-rmse:5.34402
# [114]	validation-rmse:5.34404
# [115]	validation-rmse:5.34405
# [116]	validation-rmse:5.34381
# [117]	validation-rmse:5.34376
# [118]	validation-rmse:5.34361
# [119]	validation-rmse:5.34356
# [120]	validation-rmse:5.34326
# [121]	validation-rmse:5.34318
# [122]	validation-rmse:5.34276
# [123]	validation-rmse:5.34308
# [124]	validation-rmse:5.34322
# [125]	validation-rmse:5.34335
# [126]	validation-rmse:5.34341
# [127]	validation-rmse:5.34347
# [128]	validation-rmse:5.34336
# [129]	validation-rmse:5.34351
# [130]	validation-rmse:5.34369
# [131]	validation-rmse:5.34383
# [132]	validation-rmse:5.34384
# [133]	validation-rmse:5.34347
# [134]	validation-rmse:5.34355
# [135]	validation-rmse:5.34364
# [136]	validation-rmse:5.34366
# [137]	validation-rmse:5.34345
# [138]	validation-rmse:5.34322
# [139]	validation-rmse:5.34289
# [140]	validation-rmse:5.34254
# [141]	validation-rmse:5.34245
# [142]	validation-rmse:5.34249
# [143]	validation-rmse:5.34277
# [144]	validation-rmse:5.34300
# [145]	validation-rmse:5.34299
# [146]	validation-rmse:5.34305
# [147]	validation-rmse:5.34308
# [148]	validation-rmse:5.34306
# [149]	validation-rmse:5.34301
# [150]	validation-rmse:5.34298
# [151]	validation-rmse:5.34285
# [152]	validation-rmse:5.34284
# [153]	validation-rmse:5.34268
# [154]	validation-rmse:5.34253
# [155]	validation-rmse:5.34233
# [156]	validation-rmse:5.34237
# [157]	validation-rmse:5.34247
# [158]	validation-rmse:5.34246
# [159]	validation-rmse:5.34279
# [160]	validation-rmse:5.34259
# [161]	validation-rmse:5.34274
# [162]	validation-rmse:5.34267
# [163]	validation-rmse:5.34276
# [164]	validation-rmse:5.34256
# [165]	validation-rmse:5.34253
# [166]	validation-rmse:5.34253
# [167]	validation-rmse:5.34237
# [168]	validation-rmse:5.34233
# [169]	validation-rmse:5.34219
# [170]	validation-rmse:5.34215
# [171]	validation-rmse:5.34209
# [172]	validation-rmse:5.34226
# [173]	validation-rmse:5.34223
# [174]	validation-rmse:5.34219
# [175]	validation-rmse:5.34223
# [176]	validation-rmse:5.34226
# [177]	validation-rmse:5.34223
# [178]	validation-rmse:5.34230
# [179]	validation-rmse:5.34214
# [180]	validation-rmse:5.34234
# [181]	validation-rmse:5.34219
# [182]	validation-rmse:5.34213
# [183]	validation-rmse:5.34227
# [184]	validation-rmse:5.34216
# [185]	validation-rmse:5.34225
# [186]	validation-rmse:5.34229
# [187]	validation-rmse:5.34228
# [188]	validation-rmse:5.34239
# [189]	validation-rmse:5.34228
# [190]	validation-rmse:5.34251
# [191]	validation-rmse:5.34244
# [192]	validation-rmse:5.34253
# [193]	validation-rmse:5.34248
# [194]	validation-rmse:5.34237
# [195]	validation-rmse:5.34243
# [196]	validation-rmse:5.34244
# [197]	validation-rmse:5.34253
# [198]	validation-rmse:5.34258
# [199]	validation-rmse:5.34226
# [200]	validation-rmse:5.34231
# [201]	validation-rmse:5.34234
# [202]	validation-rmse:5.34218
# [203]	validation-rmse:5.34227
# [204]	validation-rmse:5.34240
# [205]	validation-rmse:5.34273
# [206]	validation-rmse:5.34239
# [207]	validation-rmse:5.34248
# [208]	validation-rmse:5.34245
# [209]	validation-rmse:5.34252
# [210]	validation-rmse:5.34225
# [211]	validation-rmse:5.34231
# [212]	validation-rmse:5.34249
# [213]	validation-rmse:5.34252
# [214]	validation-rmse:5.34250
# [215]	validation-rmse:5.34240
# [216]	validation-rmse:5.34251
# [217]	validation-rmse:5.34260
# [218]	validation-rmse:5.34274
# [219]	validation-rmse:5.34266
# [220]	validation-rmse:5.34281
# [221]	validation-rmse:5.34272
#   6%|▌         | 3/50 [00:21<05:59,  7.65s/trial, best loss: 5.342716994933935]
# /opt/anaconda3/envs/ml/lib/python3.13/site-packages/xgboost/callback.py:386: UserWarning: [08:30:10] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation-rmse:6.37252
# [1]	validation-rmse:5.70559
# [2]	validation-rmse:5.55838
# [3]	validation-rmse:5.52600
# [4]	validation-rmse:5.50840
# [5]	validation-rmse:5.49966
# [6]	validation-rmse:5.49861
# [7]	validation-rmse:5.48624
# [8]	validation-rmse:5.48578
# [9]	validation-rmse:5.48849
# [10]	validation-rmse:5.48972
# [11]	validation-rmse:5.49115
# [12]	validation-rmse:5.48769
# [13]	validation-rmse:5.48642
# [14]	validation-rmse:5.48579
# [15]	validation-rmse:5.48597
# [16]	validation-rmse:5.48603
# [17]	validation-rmse:5.48561
# [18]	validation-rmse:5.48638
# [19]	validation-rmse:5.48728
# [20]	validation-rmse:5.48815
# [21]	validation-rmse:5.48670
# [22]	validation-rmse:5.48638
# [23]	validation-rmse:5.48414
# [24]	validation-rmse:5.48381
# [25]	validation-rmse:5.48325
# [26]	validation-rmse:5.48413
# [27]	validation-rmse:5.48433
# [28]	validation-rmse:5.48527
# [29]	validation-rmse:5.48641
# [30]	validation-rmse:5.48732
# [31]	validation-rmse:5.48800
# [32]	validation-rmse:5.48843
# [33]	validation-rmse:5.48866
# [34]	validation-rmse:5.49012
# [35]	validation-rmse:5.48974
# [36]	validation-rmse:5.49138
# [37]	validation-rmse:5.49227
# [38]	validation-rmse:5.49321
# [39]	validation-rmse:5.49416
# [40]	validation-rmse:5.49692
# [41]	validation-rmse:5.49791
# [42]	validation-rmse:5.49959
# [43]	validation-rmse:5.50001
# [44]	validation-rmse:5.50212
# [45]	validation-rmse:5.50173
# [46]	validation-rmse:5.50118
# [47]	validation-rmse:5.50345
# [48]	validation-rmse:5.50244
# [49]	validation-rmse:5.50406
# [50]	validation-rmse:5.50446
# [51]	validation-rmse:5.50577
# [52]	validation-rmse:5.50586
# [53]	validation-rmse:5.50629
# [54]	validation-rmse:5.50730
# [55]	validation-rmse:5.50769
# [56]	validation-rmse:5.51085
# [57]	validation-rmse:5.51265
# [58]	validation-rmse:5.51397
# [59]	validation-rmse:5.51492
# [60]	validation-rmse:5.51570
# [61]	validation-rmse:5.51661
# [62]	validation-rmse:5.51972
# [63]	validation-rmse:5.52003
# [64]	validation-rmse:5.52019
# [65]	validation-rmse:5.52069
# [66]	validation-rmse:5.52128
# [67]	validation-rmse:5.52230
# [68]	validation-rmse:5.51921
# [69]	validation-rmse:5.52018
# [70]	validation-rmse:5.52085
# [71]	validation-rmse:5.52196
# [72]	validation-rmse:5.52289
# [73]	validation-rmse:5.52444
# [74]	validation-rmse:5.52767
# [0]	validation-rmse:8.28279
# [1]	validation-rmse:7.63883
# [2]	validation-rmse:7.14709
# [3]	validation-rmse:6.76611
# [4]	validation-rmse:6.48394
# [5]	validation-rmse:6.27070
# [6]	validation-rmse:6.10670
# [7]	validation-rmse:5.98557
# [8]	validation-rmse:5.89403
# [9]	validation-rmse:5.82795
# [10]	validation-rmse:5.77590
# [11]	validation-rmse:5.73413
# [12]	validation-rmse:5.70313
# [13]	validation-rmse:5.68017
# [14]	validation-rmse:5.66095
# [15]	validation-rmse:5.64709
# [16]	validation-rmse:5.63436
# [17]	validation-rmse:5.62303
# [18]	validation-rmse:5.61486
# [19]	validation-rmse:5.60864
#   8%|▊         | 4/50 [00:24<04:23,  5.73s/trial, best loss: 5.342716994933935]
# /opt/anaconda3/envs/ml/lib/python3.13/site-packages/xgboost/callback.py:386: UserWarning: [08:30:13] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   self.starting_round = model.num_boosted_rounds()
# [20]	validation-rmse:5.60202
# [21]	validation-rmse:5.59729
# [22]	validation-rmse:5.59411
# [23]	validation-rmse:5.59224
# [24]	validation-rmse:5.58808
# [25]	validation-rmse:5.58522
# ...
# [202]	validation-rmse:5.41763
# [203]	validation-rmse:5.41751
# [204]	validation-rmse:5.41717
# [205]	validation-rmse:5.41742
# [206]	validation-rmse:5.41737
# [207]	validation-rmse:5.41684
# [208]	validation-rmse:5.41720
# [209]	validation-rmse:5.41744
# [210]	validation-rmse:5.41675
# [211]	validation-rmse:5.41469
# [212]	validation-rmse:5.41591
# [213]	validation-rmse:5.41587
# [214]	validation-rmse:5.41635
# [215]	validation-rmse:5.41620
# [216]	validation-rmse:5.41620
# [217]	validation-rmse:5.41632
# [218]	validation-rmse:5.41649
# [219]	validation-rmse:5.41658
# [220]	validation-rmse:5.41653
# [221]	validation-rmse:5.41655
# [222]	validation-rmse:5.41662
# [223]	validation-rmse:5.41753
# [224]	validation-rmse:5.41743
# [225]	validation-rmse:5.41831
# [226]	validation-rmse:5.41814
# [227]	validation-rmse:5.41845
# [228]	validation-rmse:5.41914
# [229]	validation-rmse:5.41948
# [230]	validation-rmse:5.42004
# [231]	validation-rmse:5.42019
# [0]	validation-rmse:6.72800
# [1]	validation-rmse:5.92740
# [2]	validation-rmse:5.67669
#  98%|█████████▊| 49/50 [06:40<00:06,  6.17s/trial, best loss: 5.290288211633125]
# /opt/anaconda3/envs/ml/lib/python3.13/site-packages/xgboost/callback.py:386: UserWarning: [08:36:29] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   self.starting_round = model.num_boosted_rounds()
# [3]	validation-rmse:5.58324
# [4]	validation-rmse:5.54042
# [5]	validation-rmse:5.51767
# [6]	validation-rmse:5.50187
# [7]	validation-rmse:5.47968
# [8]	validation-rmse:5.47584
# [9]	validation-rmse:5.46958
# [10]	validation-rmse:5.46551
# [11]	validation-rmse:5.46196
# [12]	validation-rmse:5.45890
# [13]	validation-rmse:5.45689
# [14]	validation-rmse:5.45510
# [15]	validation-rmse:5.45343
# [16]	validation-rmse:5.45061
# [17]	validation-rmse:5.44829
# [18]	validation-rmse:5.44773
# [19]	validation-rmse:5.44591
# [20]	validation-rmse:5.44567
# [21]	validation-rmse:5.44422
# [22]	validation-rmse:5.44333
# [23]	validation-rmse:5.44205
# [24]	validation-rmse:5.43959
# [25]	validation-rmse:5.43832
# [26]	validation-rmse:5.43670
# [27]	validation-rmse:5.43543
# [28]	validation-rmse:5.43289
# [29]	validation-rmse:5.43191
# [30]	validation-rmse:5.42981
# [31]	validation-rmse:5.42904
# [32]	validation-rmse:5.42825
# [33]	validation-rmse:5.42694
# [34]	validation-rmse:5.42610
# [35]	validation-rmse:5.42568
# [36]	validation-rmse:5.42470
# [37]	validation-rmse:5.42383
# [38]	validation-rmse:5.42374
# [39]	validation-rmse:5.42306
# [40]	validation-rmse:5.42226
# [41]	validation-rmse:5.42165
# [42]	validation-rmse:5.42128
# [43]	validation-rmse:5.42076
# [44]	validation-rmse:5.42116
# [45]	validation-rmse:5.42054
# [46]	validation-rmse:5.42030
# [47]	validation-rmse:5.41922
# [48]	validation-rmse:5.41870
# [49]	validation-rmse:5.41894
# [50]	validation-rmse:5.41870
# [51]	validation-rmse:5.41809
# [52]	validation-rmse:5.41840
# [53]	validation-rmse:5.41828
# [54]	validation-rmse:5.41921
# [55]	validation-rmse:5.41902
# [56]	validation-rmse:5.41896
# [57]	validation-rmse:5.41730
# [58]	validation-rmse:5.41820
# [59]	validation-rmse:5.41750
# [60]	validation-rmse:5.41717
# [61]	validation-rmse:5.41741
# [62]	validation-rmse:5.41780
# [63]	validation-rmse:5.41718
# [64]	validation-rmse:5.41722
# [65]	validation-rmse:5.41701
# [66]	validation-rmse:5.41566
# [67]	validation-rmse:5.41525
# [68]	validation-rmse:5.41559
# [69]	validation-rmse:5.41529
# [70]	validation-rmse:5.41573
# [71]	validation-rmse:5.41517
# [72]	validation-rmse:5.41575
# [73]	validation-rmse:5.41481
# [74]	validation-rmse:5.41484
# [75]	validation-rmse:5.41439
# [76]	validation-rmse:5.41498
# [77]	validation-rmse:5.41508
# [78]	validation-rmse:5.41540
# [79]	validation-rmse:5.41519
# [80]	validation-rmse:5.41515
# [81]	validation-rmse:5.41490
# [82]	validation-rmse:5.41502
# [83]	validation-rmse:5.41382
# [84]	validation-rmse:5.41331
# [85]	validation-rmse:5.41354
# [86]	validation-rmse:5.41321
# [87]	validation-rmse:5.41333
# [88]	validation-rmse:5.41312
# [89]	validation-rmse:5.41293
# [90]	validation-rmse:5.41322
# [91]	validation-rmse:5.41373
# [92]	validation-rmse:5.41359
# [93]	validation-rmse:5.41267
# [94]	validation-rmse:5.41172
# [95]	validation-rmse:5.41169
# [96]	validation-rmse:5.41116
# [97]	validation-rmse:5.41129
# [98]	validation-rmse:5.41123
# [99]	validation-rmse:5.41082
# [100]	validation-rmse:5.41110
# [101]	validation-rmse:5.41082
# [102]	validation-rmse:5.41070
# [103]	validation-rmse:5.41065
# [104]	validation-rmse:5.41088
# [105]	validation-rmse:5.41076
# [106]	validation-rmse:5.41105
# [107]	validation-rmse:5.41069
# [108]	validation-rmse:5.41028
# [109]	validation-rmse:5.41037
# [110]	validation-rmse:5.40993
# [111]	validation-rmse:5.41060
# [112]	validation-rmse:5.41030
# [113]	validation-rmse:5.41077
# [114]	validation-rmse:5.41102
# [115]	validation-rmse:5.41079
# [116]	validation-rmse:5.41033
# [117]	validation-rmse:5.41035
# [118]	validation-rmse:5.41058
# [119]	validation-rmse:5.41111
# [120]	validation-rmse:5.41124
# [121]	validation-rmse:5.41086
# [122]	validation-rmse:5.41143
# [123]	validation-rmse:5.41070
# [124]	validation-rmse:5.41108
# [125]	validation-rmse:5.41128
# [126]	validation-rmse:5.41110
# [127]	validation-rmse:5.41166
# [128]	validation-rmse:5.41141
# [129]	validation-rmse:5.41143
# [130]	validation-rmse:5.41167
# [131]	validation-rmse:5.41123
# [132]	validation-rmse:5.41163
# [133]	validation-rmse:5.41142
# [134]	validation-rmse:5.41146
# [135]	validation-rmse:5.41129
# [136]	validation-rmse:5.41103
# [137]	validation-rmse:5.41114
# [138]	validation-rmse:5.41072
# [139]	validation-rmse:5.41128
# [140]	validation-rmse:5.41133
# [141]	validation-rmse:5.41172
# [142]	validation-rmse:5.41180
# [143]	validation-rmse:5.41150
# [144]	validation-rmse:5.41150
# [145]	validation-rmse:5.41195
# [146]	validation-rmse:5.41193
# [147]	validation-rmse:5.41213
# [148]	validation-rmse:5.41176
# [149]	validation-rmse:5.41233
# [150]	validation-rmse:5.41241
# [151]	validation-rmse:5.41283
# [152]	validation-rmse:5.41259
# [153]	validation-rmse:5.41281
# [154]	validation-rmse:5.41286
# [155]	validation-rmse:5.41275
# [156]	validation-rmse:5.41292
# [157]	validation-rmse:5.41321
# [158]	validation-rmse:5.41322
# [159]	validation-rmse:5.41326
# [160]	validation-rmse:5.41329
# 100%|██████████| 50/50 [06:43<00:00,  8.08s/trial, best loss: 5.290288211633125]

# %%
mlflow.xgboost.autolog(disable=True)

# %%
with mlflow.start_run():
    
    train = xgb.DMatrix(X_train, label=y_train)
    valid = xgb.DMatrix(X_val, label=y_val)

    best_params = {
        'learning_rate': 0.09585355369315604,
        'max_depth': 30,
        'min_child_weight': 1.060597050922164,
        'objective': 'reg:linear',
        'reg_alpha': 0.018060244040060163,
        'reg_lambda': 0.011658731377413597,
        'seed': 42
    }

    mlflow.log_params(best_params)

    booster = xgb.train(
        params=best_params,
        dtrain=train,
        num_boost_round=1000,
        evals=[(valid, 'validation')],
        early_stopping_rounds=50
    )

    y_pred = booster.predict(valid)
    rmse = root_mean_squared_error(y_val, y_pred)
    mlflow.log_metric("rmse", rmse)

    with open("models/preprocessor.b", "wb") as f_out:
        pickle.dump(dv, f_out)
    mlflow.log_artifact("models/preprocessor.b", artifact_path="preprocessor")

    mlflow.xgboost.log_model(booster, artifact_path="models_mlflow")
# Out:
# [0]	validation-rmse:8.56745
# /opt/anaconda3/envs/ml/lib/python3.13/site-packages/xgboost/callback.py:386: UserWarning: [08:37:32] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   self.starting_round = model.num_boosted_rounds()
# [1]	validation-rmse:8.10033
# [2]	validation-rmse:7.69739
# [3]	validation-rmse:7.35105
# [4]	validation-rmse:7.05239
# [5]	validation-rmse:6.80020
# [6]	validation-rmse:6.58162
# [7]	validation-rmse:6.39726
# [8]	validation-rmse:6.24197
# [9]	validation-rmse:6.11059
# [10]	validation-rmse:6.00193
# [11]	validation-rmse:5.90700
# [12]	validation-rmse:5.82752
# [13]	validation-rmse:5.76123
# [14]	validation-rmse:5.70306
# [15]	validation-rmse:5.65560
# [16]	validation-rmse:5.61619
# [17]	validation-rmse:5.58065
# [18]	validation-rmse:5.55157
# [19]	validation-rmse:5.52734
# [20]	validation-rmse:5.50858
# [21]	validation-rmse:5.48872
# [22]	validation-rmse:5.47379
# [23]	validation-rmse:5.45957
# [24]	validation-rmse:5.44705
# [25]	validation-rmse:5.43706
# [26]	validation-rmse:5.42713
# [27]	validation-rmse:5.41891
# [28]	validation-rmse:5.41283
# [29]	validation-rmse:5.40819
# [30]	validation-rmse:5.40244
# [31]	validation-rmse:5.39854
# [32]	validation-rmse:5.39446
# [33]	validation-rmse:5.39004
# [34]	validation-rmse:5.38685
# [35]	validation-rmse:5.38264
# [36]	validation-rmse:5.37940
# [37]	validation-rmse:5.37680
# [38]	validation-rmse:5.37557
# [39]	validation-rmse:5.37446
# [40]	validation-rmse:5.37398
# [41]	validation-rmse:5.37311
# [42]	validation-rmse:5.37168
# [43]	validation-rmse:5.37012
# [44]	validation-rmse:5.36946
# [45]	validation-rmse:5.36916
# [46]	validation-rmse:5.36932
# [47]	validation-rmse:5.36798
# [48]	validation-rmse:5.36776
# [49]	validation-rmse:5.36748
# [50]	validation-rmse:5.36663
# [51]	validation-rmse:5.36598
# [52]	validation-rmse:5.36548
# [53]	validation-rmse:5.36492
# [54]	validation-rmse:5.36441
# [55]	validation-rmse:5.36382
# [56]	validation-rmse:5.36376
# [57]	validation-rmse:5.36340
# [58]	validation-rmse:5.36286
# [59]	validation-rmse:5.36263
# [60]	validation-rmse:5.36230
# [61]	validation-rmse:5.36186
# [62]	validation-rmse:5.36140
# [63]	validation-rmse:5.36125
# [64]	validation-rmse:5.36083
# [65]	validation-rmse:5.36025
# [66]	validation-rmse:5.35988
# [67]	validation-rmse:5.35907
# [68]	validation-rmse:5.35877
# [69]	validation-rmse:5.35822
# [70]	validation-rmse:5.35791
# [71]	validation-rmse:5.35767
# [72]	validation-rmse:5.35709
# [73]	validation-rmse:5.35690
# [74]	validation-rmse:5.35643
# [75]	validation-rmse:5.35613
# [76]	validation-rmse:5.35583
# [77]	validation-rmse:5.35571
# [78]	validation-rmse:5.35526
# [79]	validation-rmse:5.35491
# [80]	validation-rmse:5.35478
# [81]	validation-rmse:5.35422
# [82]	validation-rmse:5.35377
# [83]	validation-rmse:5.35366
# [84]	validation-rmse:5.35348
# [85]	validation-rmse:5.35338
# [86]	validation-rmse:5.35268
# [87]	validation-rmse:5.35238
# [88]	validation-rmse:5.35222
# [89]	validation-rmse:5.35207
# [90]	validation-rmse:5.35222
# [91]	validation-rmse:5.35211
# [92]	validation-rmse:5.35171
# [93]	validation-rmse:5.35159
# [94]	validation-rmse:5.35151
# [95]	validation-rmse:5.35146
# [96]	validation-rmse:5.35141
# [97]	validation-rmse:5.35069
# [98]	validation-rmse:5.35048
# [99]	validation-rmse:5.35015
# [100]	validation-rmse:5.35015
# [101]	validation-rmse:5.34987
# [102]	validation-rmse:5.34995
# [103]	validation-rmse:5.34937
# [104]	validation-rmse:5.34942
# [105]	validation-rmse:5.34926
# [106]	validation-rmse:5.34906
# [107]	validation-rmse:5.34844
# [108]	validation-rmse:5.34842
# [109]	validation-rmse:5.34862
# [110]	validation-rmse:5.34826
# [111]	validation-rmse:5.34813
# [112]	validation-rmse:5.34771
# [113]	validation-rmse:5.34770
# [114]	validation-rmse:5.34757
# [115]	validation-rmse:5.34715
# [116]	validation-rmse:5.34679
# [117]	validation-rmse:5.34671
# [118]	validation-rmse:5.34628
# [119]	validation-rmse:5.34616
# [120]	validation-rmse:5.34638
# [121]	validation-rmse:5.34591
# [122]	validation-rmse:5.34571
# [123]	validation-rmse:5.34564
# [124]	validation-rmse:5.34567
# [125]	validation-rmse:5.34552
# [126]	validation-rmse:5.34560
# [127]	validation-rmse:5.34526
# [128]	validation-rmse:5.34533
# [129]	validation-rmse:5.34547
# [130]	validation-rmse:5.34589
# [131]	validation-rmse:5.34586
# [132]	validation-rmse:5.34585
# [133]	validation-rmse:5.34582
# [134]	validation-rmse:5.34554
# [135]	validation-rmse:5.34515
# [136]	validation-rmse:5.34497
# [137]	validation-rmse:5.34456
# [138]	validation-rmse:5.34441
# [139]	validation-rmse:5.34410
# [140]	validation-rmse:5.34386
# [141]	validation-rmse:5.34372
# [142]	validation-rmse:5.34336
# [143]	validation-rmse:5.34309
# [144]	validation-rmse:5.34328
# [145]	validation-rmse:5.34308
# [146]	validation-rmse:5.34319
# [147]	validation-rmse:5.34327
# [148]	validation-rmse:5.34311
# [149]	validation-rmse:5.34286
# [150]	validation-rmse:5.34270
# [151]	validation-rmse:5.34285
# [152]	validation-rmse:5.34294
# [153]	validation-rmse:5.34280
# [154]	validation-rmse:5.34289
# [155]	validation-rmse:5.34278
# [156]	validation-rmse:5.34263
# [157]	validation-rmse:5.34208
# [158]	validation-rmse:5.34212
# [159]	validation-rmse:5.34266
# [160]	validation-rmse:5.34248
# [161]	validation-rmse:5.34240
# [162]	validation-rmse:5.34237
# [163]	validation-rmse:5.34236
# [164]	validation-rmse:5.34202
# [165]	validation-rmse:5.34197
# [166]	validation-rmse:5.34191
# [167]	validation-rmse:5.34147
# [168]	validation-rmse:5.34132
# [169]	validation-rmse:5.34079
# [170]	validation-rmse:5.34038
# [171]	validation-rmse:5.34056
# [172]	validation-rmse:5.34046
# [173]	validation-rmse:5.34030
# [174]	validation-rmse:5.34022
# [175]	validation-rmse:5.34033
# [176]	validation-rmse:5.34043
# [177]	validation-rmse:5.34047
# [178]	validation-rmse:5.34036
# [179]	validation-rmse:5.34031
# [180]	validation-rmse:5.34035
# [181]	validation-rmse:5.34027
# [182]	validation-rmse:5.34003
# [183]	validation-rmse:5.34007
# [184]	validation-rmse:5.34005
# [185]	validation-rmse:5.34004
# [186]	validation-rmse:5.34000
# [187]	validation-rmse:5.34006
# [188]	validation-rmse:5.33954
# [189]	validation-rmse:5.33955
# [190]	validation-rmse:5.33951
# [191]	validation-rmse:5.33999
# [192]	validation-rmse:5.33981
# [193]	validation-rmse:5.33976
# [194]	validation-rmse:5.33882
# [195]	validation-rmse:5.33889
# [196]	validation-rmse:5.33881
# [197]	validation-rmse:5.33905
# [198]	validation-rmse:5.33890
# [199]	validation-rmse:5.33890
# [200]	validation-rmse:5.33859
# [201]	validation-rmse:5.33850
# [202]	validation-rmse:5.33840
# [203]	validation-rmse:5.33835
# [204]	validation-rmse:5.33823
# [205]	validation-rmse:5.33811
# [206]	validation-rmse:5.33777
# [207]	validation-rmse:5.33786
# [208]	validation-rmse:5.33761
# [209]	validation-rmse:5.33761
# [210]	validation-rmse:5.33793
# [211]	validation-rmse:5.33798
# [212]	validation-rmse:5.33743
# [213]	validation-rmse:5.33743
# [214]	validation-rmse:5.33731
# [215]	validation-rmse:5.33718
# [216]	validation-rmse:5.33719
# [217]	validation-rmse:5.33668
# [218]	validation-rmse:5.33681
# [219]	validation-rmse:5.33712
# [220]	validation-rmse:5.33734
# [221]	validation-rmse:5.33729
# [222]	validation-rmse:5.33712
# [223]	validation-rmse:5.33679
# [224]	validation-rmse:5.33697
# [225]	validation-rmse:5.33714
# [226]	validation-rmse:5.33713
# [227]	validation-rmse:5.33691
# [228]	validation-rmse:5.33746
# [229]	validation-rmse:5.33729
# [230]	validation-rmse:5.33729
# [231]	validation-rmse:5.33753
# [232]	validation-rmse:5.33734
# [233]	validation-rmse:5.33738
# [234]	validation-rmse:5.33728
# [235]	validation-rmse:5.33677
# [236]	validation-rmse:5.33669
# [237]	validation-rmse:5.33656
# [238]	validation-rmse:5.33640
# [239]	validation-rmse:5.33635
# [240]	validation-rmse:5.33635
# [241]	validation-rmse:5.33629
# [242]	validation-rmse:5.33638
# [243]	validation-rmse:5.33624
# [244]	validation-rmse:5.33618
# [245]	validation-rmse:5.33614
# [246]	validation-rmse:5.33620
# [247]	validation-rmse:5.33627
# [248]	validation-rmse:5.33648
# [249]	validation-rmse:5.33637
# [250]	validation-rmse:5.33636
# [251]	validation-rmse:5.33654
# [252]	validation-rmse:5.33618
# [253]	validation-rmse:5.33602
# [254]	validation-rmse:5.33590
# [255]	validation-rmse:5.33598
# [256]	validation-rmse:5.33599
# [257]	validation-rmse:5.33629
# [258]	validation-rmse:5.33624
# [259]	validation-rmse:5.33612
# [260]	validation-rmse:5.33578
# [261]	validation-rmse:5.33573
# [262]	validation-rmse:5.33566
# [263]	validation-rmse:5.33545
# [264]	validation-rmse:5.33544
# [265]	validation-rmse:5.33512
# [266]	validation-rmse:5.33510
# [267]	validation-rmse:5.33555
# [268]	validation-rmse:5.33545
# [269]	validation-rmse:5.33556
# [270]	validation-rmse:5.33573
# [271]	validation-rmse:5.33591
# [272]	validation-rmse:5.33584
# [273]	validation-rmse:5.33583
# [274]	validation-rmse:5.33602
# [275]	validation-rmse:5.33597
# [276]	validation-rmse:5.33591
# [277]	validation-rmse:5.33575
# [278]	validation-rmse:5.33568
# [279]	validation-rmse:5.33572
# [280]	validation-rmse:5.33570
# [281]	validation-rmse:5.33554
# [282]	validation-rmse:5.33537
# [283]	validation-rmse:5.33531
# [284]	validation-rmse:5.33536
# [285]	validation-rmse:5.33531
# [286]	validation-rmse:5.33541
# [287]	validation-rmse:5.33539
# [288]	validation-rmse:5.33537
# [289]	validation-rmse:5.33528
# [290]	validation-rmse:5.33539
# [291]	validation-rmse:5.33483
# [292]	validation-rmse:5.33475
# [293]	validation-rmse:5.33480
# [294]	validation-rmse:5.33458
# [295]	validation-rmse:5.33477
# [296]	validation-rmse:5.33462
# [297]	validation-rmse:5.33469
# [298]	validation-rmse:5.33478
# [299]	validation-rmse:5.33485
# [300]	validation-rmse:5.33458
# [301]	validation-rmse:5.33453
# [302]	validation-rmse:5.33443
# [303]	validation-rmse:5.33475
# [304]	validation-rmse:5.33405
# [305]	validation-rmse:5.33353
# [306]	validation-rmse:5.33366
# [307]	validation-rmse:5.33370
# [308]	validation-rmse:5.33348
# [309]	validation-rmse:5.33350
# [310]	validation-rmse:5.33354
# [311]	validation-rmse:5.33355
# [312]	validation-rmse:5.33347
# [313]	validation-rmse:5.33341
# [314]	validation-rmse:5.33353
# [315]	validation-rmse:5.33342
# [316]	validation-rmse:5.33373
# [317]	validation-rmse:5.33379
# [318]	validation-rmse:5.33379
# [319]	validation-rmse:5.33399
# [320]	validation-rmse:5.33397
# [321]	validation-rmse:5.33379
# [322]	validation-rmse:5.33392
# [323]	validation-rmse:5.33405
# [324]	validation-rmse:5.33362
# [325]	validation-rmse:5.33359
# [326]	validation-rmse:5.33349
# [327]	validation-rmse:5.33350
# [328]	validation-rmse:5.33315
# [329]	validation-rmse:5.33313
# [330]	validation-rmse:5.33317
# [331]	validation-rmse:5.33312
# [332]	validation-rmse:5.33309
# [333]	validation-rmse:5.33308
# [334]	validation-rmse:5.33320
# [335]	validation-rmse:5.33330
# [336]	validation-rmse:5.33314
# [337]	validation-rmse:5.33318
# [338]	validation-rmse:5.33324
# [339]	validation-rmse:5.33334
# [340]	validation-rmse:5.33354
# [341]	validation-rmse:5.33333
# [342]	validation-rmse:5.33329
# [343]	validation-rmse:5.33340
# [344]	validation-rmse:5.33338
# [345]	validation-rmse:5.33321
# [346]	validation-rmse:5.33328
# [347]	validation-rmse:5.33333
# [348]	validation-rmse:5.33332
# [349]	validation-rmse:5.33337
# [350]	validation-rmse:5.33348
# [351]	validation-rmse:5.33357
# [352]	validation-rmse:5.33359
# [353]	validation-rmse:5.33353
# [354]	validation-rmse:5.33357
# [355]	validation-rmse:5.33321
# [356]	validation-rmse:5.33319
# [357]	validation-rmse:5.33314
# [358]	validation-rmse:5.33290
# [359]	validation-rmse:5.33272
# [360]	validation-rmse:5.33304
# [361]	validation-rmse:5.33315
# [362]	validation-rmse:5.33318
# [363]	validation-rmse:5.33273
# [364]	validation-rmse:5.33241
# [365]	validation-rmse:5.33242
# [366]	validation-rmse:5.33232
# [367]	validation-rmse:5.33228
# [368]	validation-rmse:5.33255
# [369]	validation-rmse:5.33236
# [370]	validation-rmse:5.33238
# [371]	validation-rmse:5.33234
# [372]	validation-rmse:5.33199
# [373]	validation-rmse:5.33193
# [374]	validation-rmse:5.33208
# [375]	validation-rmse:5.33196
# [376]	validation-rmse:5.33201
# [377]	validation-rmse:5.33204
# [378]	validation-rmse:5.33197
# [379]	validation-rmse:5.33231
# [380]	validation-rmse:5.33213
# [381]	validation-rmse:5.33225
# [382]	validation-rmse:5.33220
# [383]	validation-rmse:5.33225
# [384]	validation-rmse:5.33211
# [385]	validation-rmse:5.33204
# [386]	validation-rmse:5.33241
# [387]	validation-rmse:5.33229
# [388]	validation-rmse:5.33231
# [389]	validation-rmse:5.33241
# [390]	validation-rmse:5.33258
# [391]	validation-rmse:5.33259
# [392]	validation-rmse:5.33257
# [393]	validation-rmse:5.33247
# [394]	validation-rmse:5.33250
# [395]	validation-rmse:5.33243
# [396]	validation-rmse:5.33245
# [397]	validation-rmse:5.33261
# [398]	validation-rmse:5.33269
# [399]	validation-rmse:5.33270
# [400]	validation-rmse:5.33283
# [401]	validation-rmse:5.33283
# [402]	validation-rmse:5.33225
# [403]	validation-rmse:5.33197
# [404]	validation-rmse:5.33190
# [405]	validation-rmse:5.33193
# [406]	validation-rmse:5.33188
# [407]	validation-rmse:5.33202
# [408]	validation-rmse:5.33199
# [409]	validation-rmse:5.33188
# [410]	validation-rmse:5.33189
# [411]	validation-rmse:5.33169
# [412]	validation-rmse:5.33173
# [413]	validation-rmse:5.33173
# [414]	validation-rmse:5.33172
# [415]	validation-rmse:5.33178
# [416]	validation-rmse:5.33178
# [417]	validation-rmse:5.33178
# [418]	validation-rmse:5.33173
# [419]	validation-rmse:5.33169
# [420]	validation-rmse:5.33183
# [421]	validation-rmse:5.33171
# [422]	validation-rmse:5.33182
# [423]	validation-rmse:5.33171
# [424]	validation-rmse:5.33162
# [425]	validation-rmse:5.33166
# [426]	validation-rmse:5.33168
# [427]	validation-rmse:5.33146
# [428]	validation-rmse:5.33143
# [429]	validation-rmse:5.33149
# [430]	validation-rmse:5.33213
# [431]	validation-rmse:5.33221
# [432]	validation-rmse:5.33237
# [433]	validation-rmse:5.33238
# [434]	validation-rmse:5.33258
# [435]	validation-rmse:5.33238
# [436]	validation-rmse:5.33236
# [437]	validation-rmse:5.33224
# [438]	validation-rmse:5.33213
# [439]	validation-rmse:5.33212
# [440]	validation-rmse:5.33211
# [441]	validation-rmse:5.33214
# [442]	validation-rmse:5.33201
# [443]	validation-rmse:5.33213
# [444]	validation-rmse:5.33212
# [445]	validation-rmse:5.33210
# [446]	validation-rmse:5.33216
# [447]	validation-rmse:5.33209
# [448]	validation-rmse:5.33211
# [449]	validation-rmse:5.33234
# [450]	validation-rmse:5.33231
# [451]	validation-rmse:5.33245
# [452]	validation-rmse:5.33252
# [453]	validation-rmse:5.33237
# [454]	validation-rmse:5.33225
# [455]	validation-rmse:5.33230
# [456]	validation-rmse:5.33250
# [457]	validation-rmse:5.33241
# [458]	validation-rmse:5.33236
# [459]	validation-rmse:5.33241
# [460]	validation-rmse:5.33240
# [461]	validation-rmse:5.33263
# [462]	validation-rmse:5.33293
# [463]	validation-rmse:5.33315
# [464]	validation-rmse:5.33312
# [465]	validation-rmse:5.33279
# [466]	validation-rmse:5.33290
# [467]	validation-rmse:5.33316
# [468]	validation-rmse:5.33325
# [469]	validation-rmse:5.33322
# [470]	validation-rmse:5.33338
# [471]	validation-rmse:5.33314
# [472]	validation-rmse:5.33317
# [473]	validation-rmse:5.33329
# [474]	validation-rmse:5.33330
# [475]	validation-rmse:5.33336
# [476]	validation-rmse:5.33336
# [477]	validation-rmse:5.33326
# [478]	validation-rmse:5.33334
# /opt/anaconda3/envs/ml/lib/python3.13/site-packages/mlflow/xgboost/__init__.py:168: UserWarning: [08:37:42] WARNING: /Users/runner/work/xgboost/xgboost/src/c_api/c_api.cc:1427: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats.
#   xgb_model.save_model(model_data_path)
# 2025/05/25 08:37:47 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.

# %%
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor
from sklearn.svm import LinearSVR

mlflow.sklearn.autolog()

for model_class in (RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor, LinearSVR):

    with mlflow.start_run():

        mlflow.log_param("train-data-path", "./data/green_tripdata_2021-01.csv")
        mlflow.log_param("valid-data-path", "./data/green_tripdata_2021-02.csv")
        mlflow.log_artifact("models/preprocessor.b", artifact_path="preprocessor")

        mlmodel = model_class()
        mlmodel.fit(X_train, y_train)

        y_pred = mlmodel.predict(X_val)
        rmse = root_mean_squared_error(y_val, y_pred, squared=False)
        mlflow.log_metric("rmse", rmse)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 18
#      15 mlmodel.fit(X_train, y_train)
#      17 y_pred = mlmodel.predict(X_val)
# ---> 18 rmse = root_mean_squared_error(y_val, y_pred, squared=False)
#      19 mlflow.log_metric("rmse", rmse)
#
# File /opt/anaconda3/envs/ml/lib/python3.13/site-packages/sklearn/utils/_param_validation.py:194, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     191 func_sig = signature(func)
#     193 # Map *args/**kwargs to the function signature
# --> 194 params = func_sig.bind(*args, **kwargs)
#     195 params.apply_defaults()
#     197 # ignore self/cls and positional/keyword markers
#
# File /opt/anaconda3/envs/ml/lib/python3.13/inspect.py:3264, in Signature.bind(self, *args, **kwargs)
#    3259 def bind(self, /, *args, **kwargs):
#    3260     """Get a BoundArguments object, that maps the passed `args`
#    3261     and `kwargs` to the function's signature.  Raises `TypeError`
#    3262     if the passed arguments can not be bound.
#    3263     """
# -> 3264     return self._bind(args, kwargs)
#
# File /opt/anaconda3/envs/ml/lib/python3.13/inspect.py:3253, in Signature._bind(self, args, kwargs, partial)
#    3243         raise TypeError(
#    3244             'got some positional-only arguments passed as '
#    3245             'keyword arguments: {arg!r}'.format(
#    (...)
#    3250             ),
#    3251         )
#    3252     else:
# -> 3253         raise TypeError(
#    3254             'got an unexpected keyword argument {arg!r}'.format(
#    3255                 arg=next(iter(kwargs))))
#    3257 return self._bound_arguments_cls(self, arguments)
#
# TypeError: got an unexpected keyword argument 'squared'
